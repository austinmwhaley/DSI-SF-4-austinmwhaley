# %% [markdown]
# # Iteration practice with movies
#
# In this lab you'll be using the provided imdb `movies` list below as your dataset.
#
# This lab is designed to practice iteration. The normal questions are more gentle, and the challenge questions are suitable for advanced/expert python or programming-experienced students.
#
# All the questions require writing functions and also use iteration to solve. You should print out a test of each function you write.
#
# ---
#
# ### 1. Load the provided list of movies dictionaries.

# %%
# List of movies dictionaries:

movies = [
{
"name": "Usual Suspects", 
"imdb": 7.0,
"category": "Thriller"
},
{
"name": "Hitman",
"imdb": 6.3,
"category": "Action"
},
{
"name": "Dark Knight",
"imdb": 9.0,
"category": "Adventure"
},
{
"name": "The Help",
"imdb": 8.0,
"category": "Drama"
},
{
"name": "The Choice",
"imdb": 6.2,
"category": "Romance"
},
{
"name": "Colonia",
"imdb": 7.4,
"category": "Romance"
},
{
"name": "Love",
"imdb": 6.0,
"category": "Romance"
},
{
"name": "Bride Wars",
"imdb": 5.4,
"category": "Romance"
},
{
"name": "AlphaJet",
"imdb": 3.2,
"category": "War"
},
{
"name": "Ringing Crime",
"imdb": 4.0,
"category": "Crime"
},
{
"name": "Joking muck",
"imdb": 7.2,
"category": "Comedy"
},
{
"name": "What is the name",
"imdb": 9.2,
"category": "Suspense"
},
{
"name": "Detective",
"imdb": 7.0,
"category": "Suspense"
},
{
"name": "Exam",
"imdb": 4.2,
"category": "Thriller"
},
{
"name": "We Two",
"imdb": 7.2,
"category": "Romance"
}
]

# %% [markdown]
# ---
#
# ### 2. Filtering data by IMDB score
#
# #### 2.1
#
# Write a function that:
#
# 1. Accepts a single movie dictionary from the `movies` list as an argument.
# 2. Returns True if the IMDB score is above 5.5.
#
# #### 2.2 [Challenge]
#
# Write a function that:
#
# 1. Accepts the movies list and a specified category.
# 2. Returns True if the average score of the category is higher than the average score of all movies.

# %%
import numpy as np
category_ratings = []
non_category_ratings = []

def function_2(movies, category):
#     '''Returns True if the average score of the category is higher than the average score of all movies.'''
#     #print(category, ' = category')
#     #print(movies)
#     for movie in movies:
#         #print(movie)
#         for k,v in movie.items():
#             print(k, v)

    for movie in movies:
        if movie['category'] == category:
            category_ratings.append(movie['imdb'])
        else:
            non_category_ratings.append(movie['imdb'])
    
    category_ratings_mean = np.mean(category_ratings)
    non_category_ratings_mean = np.mean(non_category_ratings)
    
    #print(category_ratings)
    #print(non_category_ratings)
    
    #print(category_ratings_mean)
    #print(non_category_ratings_mean)
        
    if category_ratings_mean > non_category_ratings_mean:
        return True
    else:
        return False
    
    
function_2(movies, 'Romance')
# Out:
# False

# %% [markdown]
# ---
#
# ### 3. Creating subsets by numeric condition
#
# #### 3.1
#
# Write a function that:
#
# 1. Accepts the list of movies and a specified imdb score.
# 2. Returns the sublist of movies that have a score greater than the specified score.
#
# #### 3.2 [Expert]
#
# Write a function that:
#
# 1. Accepts the movies list as an argument.
# 2. Returns the movies list sorted first by category and then by movie according to average score and individual score, respectively.

# %%
# Your code here.

# %% [markdown]
# ---
#
# ### 4. Creating subsets by string condition
#
# #### 4.1
#
# Write a function that:
#
# 1. Accepts the movies list and a category name.
# 2. Returns the movie names within that category (case-insensitive!)
# 3. If the category is not in the data, print a message that it does not exist and return None.
#
# Recall that to convert a string to lowercase, you can use:
#
# ```python
# mystring = 'Dumb and Dumber'
# lowercase_mystring = mystring.lower()
# print lowercase_mystring
# 'dumb and dumber'
# ```
#
# #### 4.2 [Challenge]
#
# Write a function that:
#
# 1. Accepts the movies list and a "search string".
# 2. Returns a dictionary with keys `'category'` and `'title'` whose values are lists of categories that contain the search string and titles that contain the search string, respectively (case-insensitive!)

# %%
# Your code here.

# %% [markdown]
# ---
#
# ### Multiple conditions
#
# #### 5.1
#
# Write a function that:
#
# 1. Accepts the movies list and a "search criteria" variable.
# 2. If the criteria variable is numeric, return a list of movie titles with a score greater than or equal to the criteria.
# 3. If the criteria variable is a string, return a list of movie titles that match that category (case-insensitive!). If there is no match, return an empty list and print an informative message.
#
# #### 5.2 [Expert]
#
# Write a function that:
#
# 1. Accepts the movies list and a string search criteria variable.
# 2. The search criteria variable can contain within it:
#   - Boolean operations: `'AND'`, `'OR'`, and `'NOT'` (can have/be lowercase as well, I just capitalized for clarity).
#   - Search criteria specified with syntax `score=...`, `category=...`, and/or `title=...`, where the `...` indicates what to look for.
#     - If `score` is present, it means scores greater than or equal to the value.
#     - For `category` and `title`, the string indicates that the category or title must _contain_ the search string (case-insensitive).
# 3. Return the matches for the search criteria specified.

# %%
#5.2 [Expert]
import pandas as pd
import numpy as np

def cap_df(dataframe):
    
    category_column = dataframe['category'].str.upper() #String-Series
    score_column = dataframe['imdb'] #Float - Series
    name_column = dataframe['name'].str.upper() #String - Series
    
    #print(category_column, score_column, name_column)
    #print(category_column)
    #print(score_column)
    #print(name_column)
    
    df_upper = pd.concat([category_column, score_column, name_column], axis=1)
    df_upper.columns = ['CATEGORY', 'IMDB', 'NAME']
    #print(df_upper)
    return df_upper


def search_criteria_parser(search_criteria):
    exceptions_list = ['NOT', 'AND', 'OR', 'SCORE', 'CATEGORY']
    parsed_criteria = ""
    equal_split_list = []
    parsed_list = []
    split_criteria= search_criteria.split(" ")
    for i in range(len(split_criteria)):
            equal_split_list.append(split_criteria[i].split('='))
            
    #Merge Title
    n = 0
    #print(equal_split_list, ' = 0')
    for i in range(len(equal_split_list) + n):
        #print('iteration and n = ', i, n)
        
        if ((i + n)) == len(equal_split_list):
            break
            #print('---limit reached BREAK---')
        
        #print(equal_split_list[i + n], 'current') #n controls if we need to skip forward
        
        #print(equal_split_list[i + n])
        if 'TITLE' in equal_split_list[i + n]:
            parsed_list.append(equal_split_list[i + n])
            sub_list = []
            while equal_split_list[i + n][0] not in exceptions_list:
                sub_list.append(equal_split_list[i + n])
                n+=1
            
            
            #print(sub_list, len(sub_list), 'sub_list, len_sub_list')
            for v in sub_list:
                #print(parsed_list[-1][1], '1-1')
                #print(v[0], 'v[0]')
                if v[0] == 'TITLE':
                    pass
                else:
                    parsed_list[-1][1] = parsed_list[-1][1] + " " + v[0]
                #print(parsed_list, 'sub_parsed_list')
            
            n = len(sub_list) - 1
            
        else:
            parsed_list.append(equal_split_list[i + n])
        
        #print(parsed_list, 'sub_parsed_list') #DEBUG
      
    #print(parsed_list, 'final parsed_list')           
    return parsed_list


def pre_search(parsed_criteria):
    #print parsed_criteria
    #title_input and neg_title
    title_input = None
    for p in range(len(parsed_criteria)):
        #print(p)
        if parsed_criteria[p][0] == 'TITLE':
            title_input = parsed_criteria[p][1]
            #print title_input
            look_back = p - 1
            #print parsed_criteria[p][0]
            try: 
                if parsed_criteria[look_back][0] == 'NOT':
                    neg_title = True
                else:
                    neg_title = False
            except: #if there is nothing in list before TITLE cell
                neg_title = False
            
        else:
            neg_title = False
    
        
        if parsed_criteria[p][0] == 'SCORE':
            score_input = parsed_criteria[p][1]
            look_back = p - 1
            try:
                if parsed_criteria[look_back][0] == 'NOT':
                    neg_score = True
                else:
                    neg_score = False
            except:
                neg_score = False
        
        if parsed_criteria[p][0] == 'CATEGORY':
            category_input = parsed_criteria[p][1]
            look_back = p - 1
            try:
                if parsed_criteria[look_back][0] == 'NOT':
                    neg_category = True
                else:
                    neg_category = False
            except:
                neg_category = False
    
    #print(title_input, neg_title, 'title_input, neg_title')
    #print(score_input, neg_score, 'score_input, neg_score')
    #print(category_input, neg_category, 'category_input, neg_category')
    
    return title_input, score_input, category_input, neg_title, neg_score, neg_category
    
def score_search(movies, score, neg_score=None):
    return_score_list = []
    score = float(score)
    #print score, type(score) #DEBUG
    
    for index, row in movies.iterrows():
        f_row = float(row[1])
        if neg_score == True:
            if f_row <= score:
                return_score_list.append(row)
        else:
            if f_row >= score:
                return_score_list.append(row)
    
    return return_score_list


def category_search(movies, category, neg_category=False):
    return_category_list = []
    for index, row in movies.iterrows():
        if neg_category == True:
            if row[0] != category:
                return_category_list.append(row)
        else:
            if row[0] == category:
                return_category_list.append(row)
                
    return return_category_list
    

def title_search(movies, title, neg_title=False):
    return_title_list = []
    for index, row in movies.iterrows():
        if neg_title == True:
            if row[2] != title:
                return_title_list.append(row)
        else:
            if row[2] == title:
                return_title_list.append(row)
                
    return return_title_list


def search(upper_movies, score_input, neg_score,
            category_input, neg_category,
            title_input, neg_title):
    
    score_movies = pd.DataFrame(score_search(upper_movies, score_input, neg_score))
    category_movies = pd.DataFrame(category_search(upper_movies,category_input, neg_category))
    title_movies = pd.DataFrame(title_search(upper_movies, title_input, neg_title))
    
    #print(score_movies)
    #print(category_movies)
    #print(title_movies)
    
    return score_movies, category_movies, title_movies
    

    
    
    
def operator_elim(parsed_criteria, score_movies='None', category_movies='None', title_movies='None'):
    #print parsed_criteria
    operator_words = ['AND', 'OR']
    boolean_list_1 = []
    clause_dict = {}
    #print score_movies
    
    #First pass elim
    for cell_1 in parsed_criteria:
        if cell_1[0] == 'NOT':
            pass
        else:
            boolean_list_1.append(cell_1[0])
    print boolean_list_1
    print
    
    
    for cell_2 in range(len(boolean_list_1)):
        #print boolean_list_1[cell_2], type(boolean_list_1[cell_2]), 'value and type'
        if boolean_list_1[cell_2] in operator_words:
            clause_list = []
            #print boolean_list_1[cell_2]

            look_back = cell_2 - 1
            look_forward = cell_2 + 1
            #print boolean_list_1[look_back], boolean_list_1[cell_2], boolean_list_1[look_forward]
            clause_list.append(boolean_list_1[look_back])
            clause_list.append(boolean_list_1[cell_2])
            clause_list.append(boolean_list_1[look_forward])
            print clause_list
            
            #AND = 
            for cell_3 in clause_list:
                if cell_3 == 
                clause_dict[cell]
    
    
    
    

    
    
def beer_challenge(movies, search_criteria=False):
    #Due monday start of class
    #Search movies list for matching search criteria
    #search_criteria can contain one or multiple of the following
    #'score=' (if score is given=greater than or equal to value)
    #'category=' 
    #'title='
    # return all matching criteria
    
    '''FORMAT FUNCTIONS'''
    movies = pd.DataFrame(movies) 
    upper_movies = cap_df(movies)
    upper_search_criteria = search_criteria.upper()
    
    '''PARSE FUNCTIONS'''
    parsed_criteria = search_criteria_parser(upper_search_criteria)
    #print(parsed_criteria)
    
    '''PRE-SEARCH FUNCTIONS'''
    title_input, score_input, category_input, neg_title, neg_score, neg_category = pre_search(parsed_criteria)
#     print title_input, ' = title_input'
#     print score_input, ' = score_input'
#     print category_input, ' = category_input'
#     print neg_title, ' = neg_title'
#     print neg_score, ' = neg_score'
#     print neg_category, ' = neg_category'
    
    
    
    
    '''SEARCH FUNCTIONS'''
    score_movies, category_movies, title_movies = search(upper_movies, score_input, neg_score,
                             category_input, neg_category,
                             title_input, neg_title)
    
#     print score_movies
#     print
#     print category_movies
#     print
#     print title_movies
#     print
#     print parsed_criteria
    
    
    
    '''OPERATOR FUNCTIONS'''
    movie_results = operator_elim(parsed_criteria, score_movies, category_movies, title_movies)
    
    
    #print movie_results

# %%
#beer_challenge(movies, 'score=5.2 and category=Romance')
beer_challenge(movies, 'title=What is the name and not score=5.2 or category=Romance')
#beer_challenge(movies, 'title=What is the name and score=5.2)
#beer_challenge(movies, 'title=Exam not score=5.2 and category=Romance')
# Out:
# ['TITLE', 'AND', 'SCORE', 'OR', 'CATEGORY']
#
# ['TITLE', 'AND', 'SCORE']
# TITLE
# AND
# SCORE
# ['SCORE', 'OR', 'CATEGORY']
# SCORE
# OR
# CATEGORY
