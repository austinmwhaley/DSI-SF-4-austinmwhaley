# %% [markdown]
# ```
# ---
# title: Insult Classifcation
# type:  lesson + lab + demo
# duration: "1:25"
# creator:
#     name: David Yerrington
#     city: SF
# ---
# ```
# <img src="https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png" style="float: left; width: 50px; margin: 10px">
#
# #  Naive Bayes Demo / Lab + NLP
# Week 8 | 4.3
#
# ![](https://snag.gy/i5b9BX.jpg)
#
# In this dataset, we will be looking at labeled comments that look something like this:
#
# > <div style="float: left; margin-right: 20px;"><img src="https://snag.gy/xX9hMZ.jpg" style="float: left; margin-right: 10px; width: 60px;">**Moon Master99BBQ**<br>Insult Connoisseur</div>"You're all upset, defending this hipster band...and WE'RE the douches for reading the news and discussing it?  Put down the PBR, throw away the trucker hat, shave off that silly shadow-beard, put down your "99%er" sign, and get a job, ION."
#
# Fair warning, the content is fairly provacative but this type of problem is very common in the continuum of comment threads throughout the web.  You can also use this type of pipeline to build custom sentiment features for content specific domains that can be much more effecive than say TextBlob, for relatively low effort.

# %%
import pandas as pd, seaborn as sns, numpy as np, matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer 
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.learning_curve import learning_curve
from sklearn.cross_validation import train_test_split, cross_val_score, ShuffleSplit
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB

from sklearn.pipeline import Pipeline

# %matplotlib inline

sns.set_style("darkgrid")
# Out:
# /Users/davidyerrington/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/davidyerrington/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/learning_curve.py:23: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
insults_df = pd.read_csv("assets/datasets/train.csv", encoding="utf-8")

# %% [markdown]
# *There are a variety of colorful expletives observed throughout this dataset.  This activity is strictly educational though and you should excersize critical thinking dispite the potentail comedic nature of the content.*

# %%
insults_df.head()
# Out:
#    Insult             Date                                            Comment
# 0       1  20120618192155Z                               "You fuck your dad."
# 1       0  20120528192215Z  "i really don't understand your point.\xa0 It ...
# 2       0              NaN  "A\\xc2\\xa0majority of Canadians can and has ...
# 3       0              NaN  "listen if you dont wanna get married to a man...
# 4       0  20120619094753Z  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...

# %%
############
# DO NOT USE THIS CODE FOR COUNTING TOKENS!!!!
################

# import pandas as pd

# cvt = CountVectorizer(strip_accents='unicode', stop_words="english", ngram_range=(2,4))
# X_all = cvt.fit_transform(insults_df['Comment'])
# # X_all.toarray()
# # cvt.get_feature_names()

# sorted( 
#     zip(
#         cvt.vocabulary_.keys(), # <--- the previous verions uses cvt.vocabulary_.keys() which is a dictionary 
#         pd.DataFrame(
#             X_all.todense(), 
#             columns=cvt.get_feature_names()).T.sum()
#     ), 
#     key      =  lambda item: item[1],
#     reverse  =  True
# )


######
#  Use this code instead for exploring counts
#########
cvt      =  CountVectorizer(strip_accents='unicode', ngram_range=(2,4))
X_all    =  cvt.fit_transform(insults_df['Comment'])
columns  =  cvt.get_feature_names()

x_df     =  pd.DataFrame(X_all.toarray(), columns=columns)
tf_df    =  pd.DataFrame(x_df.sum(), columns=["freq"])
tf_df.sort_values("freq", ascending=False).head(10)
# Out:
# [(u'existing', 1508),
#  (u'fiasco', 1013),
#  (u'prostituted', 429),
#  (u'truce', 398),
#  (u'obsessively', 390),
#  (u'merchants', 384),
#  (u'funnier', 384),
#  (u'dumbest', 372),
#  (u'purposes', 309),
#  (u'stops', 282),
#  (u'discussing', 276),
#  (u'irresponsible', 276),
#  (u'droning', 259),
#  (u'replace', 254),
#  (u'marxists', 254),
#  (u'hookers', 250),
#  (u'rapidly', 240),
#  (u'dimwit', 226),
#  (u'outlet', 225),
#  (u'boarder', 219),
#  (u'sneering', 217),
#  (u'credit', 213),
#  (u'argentines', 206),
#  (u'giants', 195),
#  (u'knit', 192),
#  (u'inadvertently', 190),
#  (u'u2014', 179),
#  (u'welfarecheese', 178),
#  (u'legislatures', 175),
#  (u'slander', 172),
#  (u'nblow', 171),
#  (u'specifically', 160),
#  (u'lamar', 159),
#  (u'psychopaths', 159),
#  (u'systematic', 155),
#  (u'sniffing', 155),
#  (u'merit', 154),
#  (u'meri', 150),
#  (u'zdiets', 149),
#  (u'utstr', 146),
#  (u'planned', 145),
#  (u'govermet', 143),
#  (u'gdlow', 137),
#  (u'sweetheart', 134),
#  (u'campus', 133),
#  (u'stoopid', 127),
#  (u'jasonhairydawg', 126),
#  (u'teacher', 125),
#  (u'jag', 123),
#  (u'verlander', 121),
#  (u'nllaahknnis', 119),
#  (u'player', 113),
#  (u'elaborates', 113),
#  (u'smell', 113),
#  (u'decorating', 112),
#  (u'thatdick', 112),
#  (u'ants', 110),
#  (u'thier', 109),
#  (u'tools', 108),
#  (u'earn', 108),
#  (u'olds', 106),
#  (u'scrolls', 106),
#  (u'futurama', 106),
#  (u'chill', 102),
#  (u'apparent', 101),
#  (u'rest', 101),
#  (u'fully', 98),
#  (u'dodger', 95),
#  (u'overturning', 94),
#  (u'goind', 94),
#  (u'detalinging', 93),
#  (u'adultery', 93),
#  (u'forward', 92),
#  (u'licensed', 91),
#  (u'beacoup', 90),
#  (u'deathly', 88),
#  (u'style', 88),
#  (u'dhs', 87),
#  (u'technology', 87),
#  (u'strategist', 86),
#  (u'dots', 86),
#  (u'effects', 85),
#  (u'xa0spec', 85),
#  (u'2012', 85),
#  (u'sv', 84),
#  (u'hoof_hearted', 84),
#  (u'pstars', 83),
#  (u'rn', 82),
#  (u'stacy', 82),
#  (u'ho', 81),
#  (u'outlawing', 81),
#  (u'xc2', 81),
#  (u'xf6r', 79),
#  (u'beatles4life', 79),
#  (u'exams', 79),
#  (u'cushion', 77),
#  (u'libtards', 76),
#  (u'jehmu', 76),
#  (u'xa0take', 75),
#  (u'bleachers', 74),
#  (u'causing', 74),
#  (u'deportations', 74),
#  (u'gola', 74),
#  (u'medical', 74),
#  (u'obese', 73),
#  (u'rabies', 73),
#  (u'lee', 72),
#  (u'checking', 72),
#  (u'cheating', 71),
#  (u'unjust', 71),
#  (u'organizer', 71),
#  (u'skirts', 71),
#  (u'maintaining', 71),
#  (u'emontional', 71),
#  (u'odds', 71),
#  (u'u0303a', 70),
#  (u'xa0rachel', 70),
#  (u'nenvy', 70),
#  (u'xe4ljare', 70),
#  (u'compared', 70),
#  (u'qurl', 69),
#  (u'elimination', 69),
#  (u'nentirely', 69),
#  (u'moyles', 68),
#  (u'bankruptcies', 68),
#  (u'roads', 68),
#  (u'xa', 67),
#  (u'lacc', 67),
#  (u'betta', 66),
#  (u'viewer', 66),
#  (u'bored', 65),
#  (u'xa0nice', 65),
#  (u'1am', 64),
#  (u'studds', 64),
#  (u'fresh', 64),
#  (u'faceless', 64),
#  (u'humphries', 63),
#  (u'keyboard', 62),
#  (u'aren', 62),
#  (u'equipo', 62),
#  (u'nirvana', 61),
#  (u'diarrhea', 61),
#  (u'tendency', 61),
#  (u'peice', 61),
#  (u'pornographic', 61),
#  (u'ago', 61),
#  (u'listeners', 61),
#  (u'hiding', 61),
#  (u'lifestyle', 61),
#  (u'aquiring', 61),
#  (u'occupying', 60),
#  (u'likje', 60),
#  (u'fagg0t', 59),
#  (u'muppet', 59),
#  (u'leave', 59),
#  (u'wired', 59),
#  (u'richard', 59),
#  (u'register', 59),
#  (u'heads', 59),
#  (u'u2019ll', 59),
#  (u'crazies', 58),
#  (u'wounded', 58),
#  (u'lloyd', 58),
#  (u'giger', 58),
#  (u'dozen', 57),
#  (u'fuuuuck', 57),
#  (u'lyftes', 57),
#  (u'xe4rsta', 57),
#  (u'drroppn', 57),
#  (u'infamous', 57),
#  (u'whipping', 57),
#  (u'cardboard', 56),
#  (u'enters', 56),
#  (u'saints', 56),
#  (u'honey', 56),
#  (u'libturds', 56),
#  (u'reasoning', 56),
#  (u'klein', 55),
#  (u'downloading', 55),
#  (u'runways', 55),
#  (u'insane', 55),
#  (u'studying', 55),
#  (u'establishing', 54),
#  (u'saving', 54),
#  (u'searing', 54),
#  (u'davidson', 54),
#  (u'ur', 54),
#  (u'makes', 54),
#  (u'loans', 54),
#  (u'flynn', 54),
#  (u'vilseleda', 53),
#  (u'bonuses', 53),
#  (u'sayin', 53),
#  (u'collecting', 53),
#  (u'xe2', 53),
#  (u'lowered', 53),
#  (u'knockers', 53),
#  (u'panels', 52),
#  (u'ntouche', 52),
#  (u'cheers', 52),
#  (u'plan', 52),
#  (u'nstephen', 52),
#  (u'competence', 52),
#  (u'ntottenham', 52),
#  (u'transports', 52),
#  (u'greatness', 51),
#  (u'respective', 51),
#  (u'170', 51),
#  (u'driven', 51),
#  (u'xe8', 51),
#  (u'azzzz', 50),
#  (u'borrow', 50),
#  (u'creator', 50),
#  (u'turismo', 50),
#  (u'350', 50),
#  (u'manson', 49),
#  (u'muslims', 49),
#  (u'plunges', 49),
#  (u'prosecutor', 49),
#  (u'kekayaan', 49),
#  (u'saknar', 49),
#  (u'increased', 49),
#  (u'foriegn', 48),
#  (u'oaxaca', 48),
#  (u'son', 48),
#  (u'insignificant', 48),
#  (u'aquila', 48),
#  (u'deepwater', 48),
#  (u'damien', 48),
#  (u'iranian', 48),
#  (u'incident', 48),
#  (u'dressed', 48),
#  (u'stomach', 48),
#  (u'disparagement', 47),
#  (u'pbreaker', 47),
#  (u'disliked', 47),
#  (u'races', 47),
#  (u'wives', 47),
#  (u'admiral', 46),
#  (u'hos', 46),
#  (u'xf4i', 46),
#  (u'understanding', 46),
#  (u'homophobic', 46),
#  (u'lobbyist', 46),
#  (u'uploaded', 46),
#  (u'blows', 46),
#  (u'function', 46),
#  (u'exhale', 45),
#  (u'smithereens', 45),
#  (u'believer', 45),
#  (u'surged', 45),
#  (u'inserted', 45),
#  (u'slob', 45),
#  (u'anonymouse', 45),
#  (u'nurse', 45),
#  (u'concerned', 45),
#  (u'understands', 45),
#  (u'elites', 45),
#  (u'tow', 45),
#  (u'havee', 45),
#  (u'tonight', 45),
#  (u'shiite', 45),
#  (u'470', 45),
#  (u'hero', 44),
#  (u'rally', 44),
#  (u'bribes', 44),
#  (u'tear', 44),
#  (u'melt', 44),
#  (u'from1973', 44),
#  (u'aciddragon', 44),
#  (u'murk', 44),
#  (u'concedes', 43),
#  (u'mirrors', 43),
#  (u'planet', 43),
#  (u'boortz', 43),
#  (u'hours', 43),
#  (u'tested', 43),
#  (u'names', 43),
#  (u'centrist', 43),
#  (u'twain', 43),
#  (u'revised', 42),
#  (u'misfortune', 42),
#  (u'frowned', 42),
#  (u'fair', 42),
#  (u'herrera', 42),
#  (u'cite', 42),
#  (u'x94no', 42),
#  (u'bron', 42),
#  (u'condom', 42),
#  (u'rejecting', 42),
#  (u'len', 42),
#  (u'botox', 42),
#  (u'397', 41),
#  (u'collapse', 41),
#  (u'proven', 41),
#  (u'accidental', 41),
#  (u'brett', 41),
#  (u'flowing', 41),
#  (u'intelligent', 41),
#  (u'perfect', 41),
#  (u'prefrence', 41),
#  (u'cbf', 41),
#  (u'sister', 41),
#  (u'hockeybelle', 41),
#  (u'woods', 40),
#  (u'concepts', 40),
#  (u'vet', 40),
#  (u'russia', 40),
#  (u'sat', 40),
#  (u'gone', 40),
#  (u'tight', 40),
#  (u'courses', 40),
#  (u'listening', 40),
#  (u'thugs', 40),
#  (u'truth', 40),
#  (u'rigging', 40),
#  (u'gaurentee', 40),
#  (u'problem', 40),
#  (u'47s', 40),
#  (u'melissa', 39),
#  (u'incompetent', 39),
#  (u'clause', 39),
#  (u'paralleller', 39),
#  (u'emitowany', 39),
#  (u'r_dale', 39),
#  (u'number', 39),
#  (u'numerology', 39),
#  (u'funk', 39),
#  (u'macwhogal', 39),
#  (u'borderline', 39),
#  (u'los', 39),
#  (u'haven', 39),
#  (u'mills', 39),
#  (u'principal', 39),
#  (u'entities', 39),
#  (u'nerve', 39),
#  (u'trumps', 39),
#  (u'nunary', 39),
#  (u'kkkkkalamity', 39),
#  (u'npsychology', 39),
#  (u'julissa', 38),
#  (u'disfigured', 38),
#  (u'positive', 38),
#  (u'beatles', 38),
#  (u'gangster', 38),
#  (u'bombed', 38),
#  (u'sucker', 38),
#  (u'mummy', 38),
#  (u'bp', 38),
#  (u'bred', 38),
#  (u'frustration', 38),
#  (u'revenues', 37),
#  (u'ate', 37),
#  (u'afford', 37),
#  (u'samajh', 37),
#  (u'superstar', 37),
#  (u'zhark', 37),
#  (u'defend', 37),
#  (u'nlists', 37),
#  (u'mask', 37),
#  (u'vip', 37),
#  (u'gasket', 37),
#  (u'evry', 37),
#  (u'banner', 37),
#  (u'waiste', 37),
#  (u'dating', 37),
#  (u'democracy', 37),
#  (u'beneath', 37),
#  (u'demokrati', 37),
#  (u'xa0let', 37),
#  (u'xe0', 37),
#  (u'jurbinsky', 37),
#  (u'heresy', 37),
#  (u'places', 37),
#  (u'lamestream', 36),
#  (u'chasm', 36),
#  (u'wisdom', 36),
#  (u'jenkins', 36),
#  (u'sponsor', 36),
#  (u'skydome', 36),
#  (u'xa0you', 36),
#  (u'inserta', 36),
#  (u'chase', 36),
#  (u'callin', 35),
#  (u'coward', 35),
#  (u'fredddd', 35),
#  (u'raised', 35),
#  (u'nthroughout', 35),
#  (u'turned', 35),
#  (u'prius', 35),
#  (u'clergy', 35),
#  (u'complete', 35),
#  (u'punched', 35),
#  (u'lis1macd', 35),
#  (u'levels', 35),
#  (u'projects', 35),
#  (u'engage', 35),
#  (u'le', 35),
#  (u'u0165', 34),
#  (u'rerpublicans', 34),
#  (u'wvu', 34),
#  (u'veracity', 34),
#  (u'slime', 34),
#  (u'rush', 34),
#  (u'limitato', 34),
#  (u'shipped', 34),
#  (u'jumping', 34),
#  (u'self', 34),
#  (u'xab', 34),
#  (u'sides', 34),
#  (u'xa0every', 34),
#  (u'scientology', 34),
#  (u'embarrass', 34),
#  (u'hahahahahahahaha', 34),
#  (u'pussy', 34),
#  (u'bump', 34),
#  (u'everkaty', 34),
#  (u'punks', 33),
#  (u'place', 33),
#  (u'stamping', 33),
#  (u'logic', 33),
#  (u'lefts', 33),
#  (u'bm', 33),
#  (u'studied', 33),
#  (u'hol', 33),
#  (u'canvas', 33),
#  (u'ovonic', 33),
#  (u'policies', 33),
#  (u'50kg', 33),
#  (u'grandmothers', 33),
#  (u'peter8888', 33),
#  (u'pbs', 33),
#  (u'xa0hasn', 33),
#  (u'rein', 33),
#  (u'drawing', 33),
#  (u'irish', 33),
#  (u'graphical', 33),
#  (u'copy', 33),
#  (u'turn', 32),
#  (u'diagram', 32),
#  (u'comminity', 32),
#  (u'mislabel', 32),
#  (u'besitter', 32),
#  (u'xe5gar', 32),
#  (u'typically', 32),
#  (u'team', 32),
#  (u'suck', 32),
#  (u'artist', 32),
#  (u'clap', 32),
#  (u'assh', 32),
#  (u'beaks', 32),
#  (u'salts', 32),
#  (u'hitchens', 32),
#  (u'chat', 32),
#  (u'buniyad', 32),
#  (u'scary', 32),
#  (u'sits', 32),
#  (u'rule', 32),
#  (u'wing', 31),
#  (u'waaaaaaaaaaaa', 31),
#  (u'inside', 31),
#  (u'brilliant', 31),
#  (u'wisely', 31),
#  (u'exit', 31),
#  (u'respects', 31),
#  (u'akuatuta', 31),
#  (u'inquirer', 31),
#  (u'reared', 31),
#  (u'mugshots', 31),
#  (u'thot', 31),
#  (u'1932', 31),
#  (u'log', 31),
#  (u'cristina', 31),
#  (u'wrent', 31),
#  (u'functionality', 31),
#  (u'premature', 31),
#  (u'brings', 30),
#  (u'schimidt', 30),
#  (u'fugitive', 30),
#  (u'nwill', 30),
#  (u'poison', 30),
#  (u'bin', 30),
#  (u'alice', 30),
#  (u'xa0about', 30),
#  (u'morteza', 30),
#  (u'khi', 30),
#  (u'becuase', 30),
#  (u'awesome', 30),
#  (u'cps', 30),
#  (u'bullshlt', 30),
#  (u'murdering', 30),
#  (u'really', 30),
#  (u'video', 30),
#  (u'espouse', 30),
#  (u'nre', 30),
#  (u'rabid', 30),
#  (u'redistribution', 30),
#  (u'norquist', 30),
#  (u'snip', 30),
#  (u'x9cat', 30),
#  (u'tter', 30),
#  (u'controversial', 30),
#  (u'criticise', 29),
#  (u'rw', 29),
#  (u'fruity', 29),
#  (u'rednecks', 29),
#  (u'nvery', 29),
#  (u'probes', 29),
#  (u'annagillmodel', 29),
#  (u'chirping', 29),
#  (u'say', 29),
#  (u'comming', 29),
#  (u'mean', 29),
#  (u'rage', 29),
#  (u'ad', 29),
#  (u'cpy', 29),
#  (u'baddest', 29),
#  (u'trillions', 29),
#  (u'salmonfly', 29),
#  (u'implore', 29),
#  (u'sinclair', 29),
#  (u'girls', 29),
#  (u'yawz', 29),
#  (u'goddamn', 29),
#  (u'c2kmuftr', 29),
#  (u'inferiority', 29),
#  (u'xa0guess', 29),
#  (u'xe5got', 29),
#  (u'stinks', 29),
#  (u'paulmomo', 28),
#  (u'lethal', 28),
#  (u'sob', 28),
#  (u'redemption', 28),
#  (u'argies', 28),
#  (u'xe9ste', 28),
#  (u'axlrodes', 28),
#  (u'fooled', 28),
#  (u'photos', 28),
#  (u'world', 28),
#  (u'sand', 28),
#  (u'allm', 28),
#  (u'leverage', 28),
#  (u'sinner', 28),
#  (u'of_the_fuckyou_hat', 28),
#  (u'qi1ly', 28),
#  (u'retina', 28),
#  (u'commi', 28),
#  (u'husbanding', 28),
#  (u'classs', 28),
#  (u'rough', 28),
#  (u'elmer', 28),
#  (u'generous', 28),
#  (u'sharia', 28),
#  (u'xa8', 27),
#  (u'goddammit', 27),
#  (u'ngame', 27),
#  (u'nturn', 27),
#  (u'transgender', 27),
#  (u'wetshoes', 27),
#  (u'believing', 27),
#  (u'dickwrinkles', 27),
#  (u'harshest', 27),
#  (u'nshut', 27),
#  (u'buffet', 27),
#  (u'average', 27),
#  (u'costa', 27),
#  (u'summed', 27),
#  (u'fundraising', 27),
#  (u'cowhide', 27),
#  (u'abolish', 27),
#  (u'estimate', 27),
#  (u'kless', 27),
#  (u'npgh', 27),
#  (u'mexican', 27),
#  (u'obamawon', 27),
#  (u'folks', 27),
#  (u'counter', 27),
#  (u'scare', 27),
#  (u'carlson', 27),
#  (u'literally', 27),
#  (u'everybody', 27),
#  (u'stereotypical', 26),
#  (u'nigs', 26),
#  (u'cyclical', 26),
#  (u'hurt', 26),
#  (u'travel', 26),
#  (u'geithner', 26),
#  (u'destined', 26),
#  (u'size', 26),
#  (u'ncall', 26),
#  (u'plate', 26),
#  (u'xa0really', 26),
#  (u'wikipedia', 26),
#  (u'px2n02qy', 26),
#  (u'avila', 26),
#  (u'stokes', 26),
#  (u'facility', 26),
#  (u'_fuck_off_nigger_you', 26),
#  (u'spanish', 26),
#  (u'alley', 26),
#  (u'vart', 26),
#  (u'carolina', 26),
#  (u'stream', 26),
#  (u'shockwave', 26),
#  (u'trips', 26),
#  (u'sense', 26),
#  (u'waves', 26),
#  (u'sueltan', 26),
#  (u'stevens', 26),
#  (u'xa0william', 26),
#  (u'currently', 26),
#  (u'cabbage', 26),
#  (u'sadler', 26),
#  (u'populace', 26),
#  (u'myclerk', 26),
#  (u'ranga', 26),
#  (u'packed', 26),
#  (u'quotas', 26),
#  (u'bradly', 26),
#  (u'lust', 26),
#  (u'babylon', 26),
#  (u'funney', 26),
#  (u'smooth', 26),
#  (u'hordes', 25),
#  (u'yellow', 25),
#  (u'criticism', 25),
#  (u'boston', 25),
#  (u'barret', 25),
#  (u'chile', 25),
#  (u'exist', 25),
#  (u'passengers', 25),
#  (u'u0103', 25),
#  (u'caucasus', 25),
#  (u'reveal', 25),
#  (u'date', 25),
#  (u'u1ec9nh', 25),
#  (u'redirected', 25),
#  (u'imagined', 25),
#  (u'your_nasty', 25),
#  (u'famousoriginallucas', 25),
#  (u'technically', 25),
#  (u'walker', 25),
#  (u'caused', 25),
#  (u'xa0will', 25),
#  (u'scott', 25),
#  (u'reduce', 25),
#  (u'thank', 25),
#  (u'baba', 25),
#  (u'xe4ckligt', 25),
#  (u'megan', 25),
#  (u'assholes', 25),
#  (u'ce', 25),
#  (u'vs', 25),
#  (u'cslos77', 25),
#  (u'documentary', 25),
#  (u'pharmacy', 24),
#  (u'cocaine', 24),
#  (u'effective', 24),
#  (u'feedback', 24),
#  (u'dillusional', 24),
#  (u'checked', 24),
#  (u'speedy', 24),
#  (u'xa0getting', 24),
#  (u'busy', 24),
#  (u'canyon', 24),
#  (u'hai', 24),
#  (u'sox', 24),
#  (u'manufacturers', 24),
#  (u'helathy', 24),
#  (u'address', 24),
#  (u'parades', 24),
#  (u'disgracing', 24),
#  (u'moralizuj', 24),
#  (u'kotor', 24),
#  (u'angelos', 24),
#  (u'xa0living', 24),
#  (u'klu', 24),
#  (u'gallon', 24),
#  (u'evo', 24),
#  (u'celeb', 24),
#  (u'body', 24),
#  (u'victims', 24),
#  (u'lunacy', 24),
#  (u'natives', 24),
#  (u'doj', 24),
#  (u'visiting', 24),
#  (u'4214', 24),
#  (u'consideration', 24),
#  (u'x9ccommunity', 24),
#  (u'practicing', 24),
#  (u'u201cgay', 24),
#  (u'nancy', 24),
#  (u'detta', 24),
#  (u'centinaia', 24),
#  (u'recognize', 24),
#  (u'consenting', 23),
#  (u'allowscriptaccess', 23),
#  (u'ar_rihanna', 23),
#  (u'fin', 23),
#  (u'ufeff4', 23),
#  (u'singer', 23),
#  (u'meetings', 23),
#  (u'nsome', 23),
#  (u'campaigning', 23),
#  (u'shadow', 23),
#  (u'pest', 23),
#  (u'kit28', 23),
#  (u'suspicion', 23),
#  (u'crushing', 23),
#  (u'allahpundit', 23),
#  (u'defication', 23),
#  (u'sidestepping', 23),
#  (u'screen', 23),
#  (u'adept', 23),
#  (u'trabert', 23),
#  (u'xa0who', 23),
#  (u'door', 23),
#  (u'xa0bill', 23),
#  (u'dislikes', 23),
#  (u'treatments', 23),
#  (u'easterner', 23),
#  (u'investigators', 23),
#  (u'votos', 23),
#  (u'imagine', 23),
#  (u'vilonce', 23),
#  (u'jacinto', 23),
#  (u'ler', 23),
#  (u'indefinite', 23),
#  (u'carbondale', 23),
#  (u'feces', 23),
#  (u'prensa', 23),
#  (u'arkan', 23),
#  (u'uh', 23),
#  (u'nones', 23),
#  (u'brey', 23),
#  (u'familiar', 23),
#  (u'wring', 23),
#  (u'xa310', 23),
#  (u'dat', 23),
#  (u'smithsonian', 23),
#  (u'spew', 23),
#  (u'theirselves', 22),
#  (u'climate', 22),
#  (u'freak', 22),
#  (u'asia', 22),
#  (u'dejo', 22),
#  (u'parallels', 22),
#  (u'lookin', 22),
#  (u'x9cthere', 22),
#  (u'spews', 22),
#  (u'letterman', 22),
#  (u'officiating', 22),
#  (u'statements', 22),
#  (u'xe4tta', 22),
#  (u'center', 22),
#  (u'serialized', 22),
#  (u'impacted', 22),
#  (u'ineffective', 22),
#  (u'films', 22),
#  (u'collapsing', 22),
#  (u'loudly', 22),
#  (u'dark', 22),
#  (u'biases', 22),
#  (u'burglar', 22),
#  (u'ar', 22),
#  (u'tours', 22),
#  (u'detention', 22),
#  (u'sang', 22),
#  (u'qiai2', 22),
#  (u'xa0again', 22),
#  (u'speculate', 22),
#  (u'depressingly', 22),
#  (u'aac', 22),
#  (u'banking', 22),
#  (u'mind', 22),
#  (u'litigate', 22),
#  (u'lana', 22),
#  (u'directive', 22),
#  (u'sunnuva', 22),
#  (u'hope', 22),
#  (u'jussi', 22),
#  (u'identity', 22),
#  (u'realize', 22),
#  (u'elitist', 22),
#  (u'schedule', 22),
#  (u'count', 22),
#  (u'nnorthern', 22),
#  (u'placed', 22),
#  (u'regional', 21),
#  (u'cult', 21),
#  (u'duniya', 21),
#  (u'18th', 21),
#  (u'mason', 21),
#  (u'hypothetical', 21),
#  (u'corny', 21),
#  (u'nel', 21),
#  (u'demanded', 21),
#  (u'lltrix', 21),
#  (u'256', 21),
#  (u'ownership', 21),
#  (u'prison', 21),
#  (u'raped', 21),
#  (u'joseph', 21),
#  (u'nwaaaaa', 21),
#  (u'intent', 21),
#  (u'ose', 21),
#  (u'minute', 21),
#  (u'sensability', 21),
#  (u'bloody', 21),
#  (u'hon', 21),
#  (u'pr1ck', 21),
#  (u'commissar', 21),
#  (u'nappeal', 21),
#  (u'remarks', 21),
#  (u'inconsistent', 21),
#  (u'midfing', 21),
#  (u'60', 21),
#  (u'rectums', 21),
#  (u'nmcdonnell', 21),
#  (u'scientists', 21),
#  (u'doom', 21),
#  (u'epoch', 21),
#  (u'xa0one', 21),
#  (u'colton', 21),
#  (u'recent', 21),
#  (u'ba', 21),
#  (u'bh', 21),
#  (u'xe4ndra', 21),
#  (u'lampard', 21),
#  (u'uk', 21),
#  (u'robots', 21),
#  (u'plcp', 21),
#  (u'gon', 21),
#  (u'enigmatic', 21),
#  (u'lawmanjed', 21),
#  (u'jacqueline', 21),
#  (u'means', 21),
#  (u'join', 21),
#  (u'salem', 21),
#  (u'compares', 21),
#  (u'eussr', 21),
#  (u'screaming', 20),
#  (u'u1ed1i', 20),
#  (u'telegraph', 20),
#  (u'absolute', 20),
#  (u'rs', 20),
#  (u'carson', 20),
#  (u'cops', 20),
#  (u'wauwatosa', 20),
#  (u'union', 20),
#  (u'ole', 20),
#  (u'harassment', 20),
#  (u'evenko', 20),
#  (u'xa0system', 20),
#  (u'nsecond', 20),
#  (u'nwhat', 20),
#  (u'bli', 20),
#  (u'pentru', 20),
#  (u'millionaire', 20),
#  (u'fuktwatcockbitchfag', 20),
#  (u'math', 20),
#  (u'morons', 20),
#  (u'xa0lmfao', 20),
#  (u'prior', 20),
#  (u'science', 20),
#  (u'morgan', 20),
#  (u'alls', 20),
#  (u'exhibited', 20),
#  (u'critically', 20),
#  (u'fights', 20),
#  (u'set', 20),
#  (u'towns', 20),
#  (u'innuendo', 20),
#  (u'2030', 20),
#  (u'input', 20),
#  (u'dougengland', 20),
#  (u'poster', 20),
#  (u'walked', 20),
#  (u'marry', 20),
#  (u'involves', 20),
#  (u'fuckdamn', 20),
#  (u'bend', 20),
#  (u'classy', 20),
#  (u'klaners', 20),
#  (u'agriculture', 20),
#  (u'xa0thanks', 20),
#  (u'estrich', 20),
#  (u'tier', 20),
#  (u'visa', 20),
#  (u'loathed', 20),
#  (u'replacement', 20),
#  (u'hards', 20),
#  (u'fru', 20),
#  (u'consumed', 20),
#  (u'controled', 19),
#  (u'nwhen', 19),
#  (u'sellout', 19),
#  (u'fail', 19),
#  (u'stamps', 19),
#  (u'xa028', 19),
#  (u'defensive', 19),
#  (u'bollocks', 19),
#  (u'educate', 19),
#  (u'abortion', 19),
#  (u'st', 19),
#  (u'nsimplement', 19),
#  (u'sau', 19),
#  (u'lick', 19),
#  (u'combined', 19),
#  (u'denying', 19),
#  (u'postal', 19),
#  (u'pakistanio', 19),
#  (u'acc', 19),
#  (u'sent', 19),
#  (u'epoca', 19),
#  (u'u201d', 19),
#  (u'bhi', 19),
#  (u'ninth', 19),
#  (u'tacoma', 19),
#  (u'follicles', 19),
#  (u'conversation', 19),
#  (u'suit', 19),
#  (u'sided', 19),
#  (u'carrying', 19),
#  (u'ncraig', 19),
#  (u'continued', 19),
#  (u'nme', 19),
#  (u'demand', 19),
#  (u'shorts', 19),
#  (u'mountainous', 19),
#  (u'taxes', 19),
#  (u'defenseman', 19),
#  (u'xe1c', 19),
#  (u'insanely', 19),
#  (u'onner', 19),
#  (u'charities', 19),
#  (u'goldschmidt', 18),
#  (u'ronnie', 18),
#  (u'ntroll', 18),
#  (u'purpose', 18),
#  (u'light', 18),
#  (u'person', 18),
#  (u'dumbfuck', 18),
#  (u'rick', 18),
#  (u'ugly', 18),
#  (u'sju', 18),
#  (u'masons', 18),
#  (u'nkrish', 18),
#  (u'dues', 18),
#  (u'proves', 18),
#  (u'marathon', 18),
#  (u'pen', 18),
#  (u'stays', 18),
#  (u'stole', 18),
#  (u'missar', 18),
#  (u'disasters', 18),
#  (u'naked', 18),
#  (u'8500', 18),
#  (u'boyfriend', 18),
#  (u'roadside', 18),
#  (u'xa0honestly', 18),
#  (u'actors', 18),
#  (u'retract', 18),
#  (u'divine', 18),
#  (u'kuch', 18),
#  (u'disgraceful', 18),
#  (u'laying', 18),
#  (u'biblical_law2', 18),
#  (u'browns', 18),
#  (u'reminded', 18),
#  (u'labeling', 18),
#  (u'operation', 18),
#  (u'jer', 18),
#  (u'river', 18),
#  (u'scousers', 18),
#  (u'bengal', 18),
#  (u'bb', 18),
#  (u'sacrament', 18),
#  (u'slump', 18),
#  (u'nnanananana', 18),
#  (u'hello', 18),
#  (u'debauched', 18),
#  (u'wedge', 18),
#  (u'meantime', 18),
#  (u'2011', 18),
#  (u'2010', 18),
#  (u'regulators', 18),
#  (u'depressing', 18),
#  (u'genetic', 18),
#  (u'hateful', 18),
#  (u'romance', 18),
#  (u'gorgeous', 18),
#  (u'february', 18),
#  (u'ngood', 18),
#  (u'poor', 18),
#  (u'prices', 17),
#  (u'fiesty', 17),
#  (u'misandry', 17),
#  (u'holy', 17),
#  (u'locked', 17),
#  ...]

# %% [markdown]
# ### 1. Explore a list of comment words that occur more than 50x
# Plot a histogram of some kind might be helpful.

# %%
cvt = CountVectorizer()
X_all = cvt.fit_transform(insults_df["Comment"])

## Complete your code -- observe the desired output already below frame

# %% [markdown]
# ### 1.5 Try it again with stopword removal

# %%
import re, urllib

# Ignore this -- wanted to mine links inside of these "bad" insult comments
# def mine_links(val):
#     GRUBER_URLINTEXT_PAT = re.compile(ur'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?\xab\xbb\u201c\u201d\u2018\u2019]))')
#     print GRUBER_URLINTEXT_PAT.findall(val)
    
# insults_df["Comment"].map(mine_links)

# %%
cvt = CountVectorizer(stop_words="english")
X_all = cvt.fit_transform(insults_df["Comment"])

# Finish code

# %% [markdown]
# ### 2. Explore ngrams between 2 and 4
# Display the top 75 ngrams with frequencies.  Look at each class to see how they are same / different.

# %%
cvt = CountVectorizer? # look up the appropriate parameters
# Out:
# [(u'xc2 xa0', 379), (u'xe2 x80', 209), (u'xa0 xa0', 144), (u'http shar', 68), (u'http shar es', 68), (u'shar es', 68), (u'trade trade', 63), (u'trade trade trade', 62), (u'u2026 u2026', 59), (u'xa0 xa0 xa0', 57), (u'u2026 u2026 u2026', 52), (u'xc2 xa0 xc2', 46), (u'xa0 xc2', 46), (u'don know', 43), (u'x80 x99s', 41), (u'xe2 x80 x99s', 41), (u'xa0 xc2 xa0', 35), (u'look like', 35), (u'bit ly', 34), (u'x80 x9d', 34), (u'xe2 x80 x9d', 34), (u'bit ly mrzlgv', 32), (u'gay marriage', 32), (u'ly mrzlgv', 32), (u'x80 x99t', 30), (u'xe2 x80 x99t', 30), (u'http bit', 28), (u'http bit ly', 28), (u'looks like', 26), (u'just like', 24), (u'ly mrzlgv http', 24), (u'mrzlgv http', 24), (u'xa0 just', 23), (u'people like', 23), (u'united states', 23), (u'sound like', 23), (u'don like', 20), (u'don think', 19), (u'mrzlgv http shar', 18), (u'nhttp www', 18), (u'ha ha', 17), (u'ron paul', 17), (u'don understand', 17), (u'xa0 don', 17), (u'fox news', 16), (u'democrat representative', 16), (u'years ago', 15), (u'xe3 x80', 15), (u'www youtube', 15), (u'u03dfc shock', 15), (u'youtube com', 15), (u'www youtube com', 15), (u'xe2 x80 xa6', 14), (u'people don', 14), (u'x80 xa6', 14), (u'big deal', 14), (u'http www', 14), (u'right wing', 14), (u'black people', 13), (u'just want', 13), (u'don want', 13), (u'sounds like', 13), (u'act like', 13), (u'com watch', 13), (u'youtube com watch', 13), (u'xc2 xa0i', 13), (u'don care', 13), (u'year old', 12), (u'pleaded guilty', 12), (u'doesn make', 12), (u'disqus com guest', 12), (u'don forget', 12), (u'xa0 people', 12), (u'dont know', 12), (u'com guest', 12)]

# %% [markdown]
# ### 3. (Optional) try expanding the list of stopwords
# There's definitely some extra crap floating around our lovely ngrams like xa0, x80, web urls, and a bunch of other things.  If you could remove them, this could help us improve the score.  Identify words / tokens that don't add much value to either class.  **You should additionally look at ngrams per class (insults vs non-insults) to fine tune your preprocessing.  This has the greatest potential to improve your results without tuning any model parameters.**
#
# Using `nltk.corpus`, we can get a baseline list of stop words.  Try to expand it and pass it to our vectorizer.

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %% [markdown]
# ### 4. Setup a test / train split of your data using any method you wish.
# Try 70/30 to start.

# %%
# Out:
# (2762, 1960)

# %% [markdown]
# ### 5. Setup a "Pipeline" to vectorize and use MultinomialNB classifier.
# Check out our last lab to set this up.  Use lowercase, strip_accents, and optionally your updated stop_words.  Fit your comment data using your "Insult" feature as your response.
#
# Fit your training data to your pipeline, then score it.

# %%
# Here's the code -- you can adapt it from here on out.
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('cls', MultinomialNB())
]) 
pipeline.fit(insults_df["Comment"], insults_df["Insult"])

# don't forget to score
# Out:
# Pipeline(steps=[('vect', CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         st...False,
#          use_idf=True)), ('cls', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %% [markdown]
# ### 5.5a Swap out MultinomialNB with BernoulliNB in the pipeline
# How do they compare?

# %% [markdown]
# ### 5.5a Also try logistic regression, and random forrests in the pipeline
# How do they compare?

# %% [markdown]
# #### 5.5b Also try tweeking the paramters of CountVectorizer and TfidfTranformer.
#
# Remove Tfidf also. Good / bad?

# %% [markdown]
# ### 6. Check your score.
# Also, run a classification report and [plot AUC/ROC](../../week-04/2.3-evaluating_model_fit/code/AUC-ROC-codealong.ipynb).  Also, [review classfication reporting metrics](../../week-04/4.3-advanced-model_evaluation/code/starter-code/week4-4.1-classification-report.ipynb).

# %%
print classification_report(target_names=["Insult", "Neutral"]) # update the code to display the classification report
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-b29232bf0c5f> in <module>()
# ----> 1 print classification_report(target_names=["Insult", "Neutral"]) # update the code to display the classification report
#
# TypeError: classification_report() takes at least 2 arguments (1 given)

# %% [markdown]
# ### Revisiting:  Learning Curves
#
# ![](https://snag.gy/GoUvNw.jpg)
#
# We touched on this briefly in the past but lets reprise the idea of sample size effect on validation score.  How do we know the optimal sample size to train and test on?  We can examine the scores of training and cross validation given a number of samples.  Plotting the scores is a great way to understand:
#
# - How to improve bias / generalization (out of sample prediction)
# - Generally how many samples you might need
# - The bounds of your models performance
#
# Generally, the learning curves represent the number of samples that have been used, the average scores on the training sets and the average scores on the validation sets.
#
# See also [validation curves](http://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html#example-model-selection-plot-validation-curve-py) for model parameter *(aka: hyper parameter)* tuning, also [calibration plots](http://scikit-learn.org/stable/auto_examples/calibration/plot_compare_calibration.html).

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
# Pipeline variable can be replaced by your already established estimator
cv = ShuffleSplit(insults_df.shape[0], n_iter=100, test_size=0.6, random_state=0)
plot_learning_curve(pipeline, "Learning Curves (Naive Bayes)", insults_df['Comment'], insults_df['Insult'], ylim=(0.5, 1.01), cv=cv, n_jobs=4)
# Out:
# <module 'matplotlib.pyplot' from '/Users/davidyerrington/anaconda/envs/dsi/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %% [markdown]
# ### 6.5 Check out your baseline.
#
# What is the chance that you will randomly guess correctly without any modeling? Insult vs neutral.

# %% [markdown]
# ### 7. Check the accuracy of your model with the holdout dataset "test_with_solutions.csv"
#
# Using the `test_with_solutions.csv`, we will test our model on another set of data it has never seen before.  Also plot the same eval metrics (classification report, AUC/ROC).

# %%
holdout_df = pd.read_csv("assets/datasets/test_with_solutions.csv", encoding="utf-8")

# %% [markdown]
# ### 8. What is your model not getting right?
#
# Check out false positives and true negatives.  Any noticable patterns?  Pay particular attention to the recall metric.  What might be done in preprocessing steps to improve accuracy?
#
# - Try to improve with your **preprocessing first**
# - THEN try to tweek your **parameters to your model(s)**

# %% [markdown]
# ## Lastly...
#
# Check [this blog post](http://webmining.olariu.org/my-first-kaggle-competition-and-how-i-ranked/) by a guy who used SVM, a "neural network", a ton of cleaning, then placed 3rd in a Kaggle competition featuing this same dataset.  Given that you used a few basic techniques with preprocessing text and Naive Bayes, what do think about the tradeoffs of simplicity vs complexity of your model?
#
# #### Where Next?
#
# If you're interested in this type of problem, a great area to read up on is sentiment analysis.  This [Kaggle dataset](https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews/data) is an excellent opportunity to practice more.  Also these whitepapers are great places to expand on this topic:
#
# - [Fast and accurate sentiment classification using an
# enhanced Naive Bayes model](http://arxiv.org/pdf/1305.6143.pdf) *Great overview!*
# - [Sarcasm Detection](http://www.aclweb.org/anthology/P15-2124)
# - [Making Computers Laugh:
# Investigations in Automatic Humor Recognition](http://www.aclweb.org/anthology/H05-1067)
# - [Modelling Sarcasm in Twitter, a Novel Approach](http://www.aclweb.org/anthology/W14-2609)
# - [RUNNING HEAD: NARCISSISM AND LIE DETECTION](https://deepblue.lib.umich.edu/bitstream/handle/2027.42/107345/zarins.finalthesis.pdf?sequence=1) *The study metrics are interesting*
