# %% [markdown]
# # Spark Lab 1
#
# In this lab, we will use Spark to further dig into the Bay Area Bike Share data.
#
# You will need to run this lab on the VM provided. So, as usual, connect to your VM using
#
#     vagrant up
#     vagrant ssh
#
# And then, once inside, run:
#
#     spark_local_start.sh
#
# **Important:** If your machine is already running and you've started the Hadoop services with `bigdata_start.sh`, you may want to first run `bigdata_stop.sh` to stop all services and free some memory space.
#
# Once you've started spark in local mode, you should be able to access Jupyter at this address:
#
# http://10.211.55.101:18888
#
# We will work in there.
#
# Our goal is to calculate the average number of trips per hour, using the Caltrain Station as starting point.
#
# Check that your spark context is available:

# %%
sc
# Out:
# ''

# %% [markdown]
# Load the Bay Bay Area Bike Share trip data:
#
# NB: data has been pre-loaded on your VM

# %%
trips = sc.textFile('file:///home/vagrant/data/201408_babs_open_data/201408_trip_data.csv')

# %% [markdown]
# **Check:** What kind of object is `trips`?
#
# ### Exercise 1: split csv lines
# In spark, we can build complex pipelines that only get executed when we ask to collect them.
#
# Remember how we built pipelines in scikit learn as a composition of transformations?
#
# The process here is very similar, with one big difference:
#
# While in a python pipeline the calculation is immediately executed, with spark the pipeline definition and execution are separate steps.
#
# In other words, we can define the pipeline with all its steps, and only when we call `collect` will the data flow through it. In order to get familiar with this new workflow, we will start with small steps to build our pipeline.
#
# First step:
# - apply a map to trips that splits each line at commas and save that to a an RDD
#
# **Hint:** if you want to check that you're doing things right, you can collect the result and display the first few lines.

# %% [markdown]
# ### Exercise 2: filter for Caltrain station
# In Spark we can also create filters using the `filter` method.
# Let's select station number 70 by filtering on the 5th column, we will do all the following analysis just on this station, which corresponds to the most popular starting point. Save this to a variable called `station_70`.

# %% [markdown]
# ### Exercise 3: trips by day - hour (mapper)
# Let's analyse the trips by the hour. We can do this by performing a map reduce job in Spark. First we will need to emit tuples with a count of 1 for each (date, hour) key, and then we will sum the counts by key.
#
# - Emit tuple of ((date, hour), 1), applying a map to `station_70` that extracts the relevant data from each line

# %%
# Emit tuple of ((date, hour), 1)

# %% [markdown]
# ### Exercise 4:  trips by day - hour (reducer)
#
# Use the `reduceByKey` method to obtain the number of trips per (day, hour)

# %% [markdown]
# ### Exercise 5: trips by hour (mapper)
# Let's further group the trips by hour. We'll do this with a second Map Reduce job.
# First we will discard the day and emit tuples of (hour, count). You can achieve this with a map

# %%
# Emit tuple of (hour, count)

# %% [markdown]
# ### Exercise 6: trips by hour (reducer)
# Then let's calculate the average number of trips by hour using the `combineByKey` method.
#
# You can find a suggestion on how to do it [here](http://abshinn.github.io/python/apache-spark/2014/10/11/using-combinebykey-in-apache-spark/).

# %% [markdown]
# ### Exercise 7: collect
# We can finally collect our result and sort them

# %% [markdown]
# ### Bonus:
#
# Besides the SparkContext, Spark also exposes a sqlContext that allows us to perform SQL queries on an RDD object.
#
# A SQLContext is also already created for you. Do not create another or unspecified behavior may occur. As you can see below, the sqlContext provided is a HiveContext.
#
# - Run the same query we performed in Hue/Hive to obtain the average duration of a trip originating from the Caltrain station

# %%
sqlContext

# %%
tripsSql = sqlContext.read.format('com.databricks.spark.csv').options(header='true',
                                                                      inferschema='true').load('../../../../../../DSI-SF-2/datasets/iowa_liquor/Iowa_Liquor_sales_sample_10pct.csv')

# %%
tripsSql.printSchema()
# Out:
# root
#  |-- Date: string (nullable = true)
#  |-- Store Number: integer (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Zip Code: string (nullable = true)
#  |-- County Number: double (nullable = true)
#  |-- County: string (nullable = true)
#  |-- Category: double (nullable = true)
#  |-- Category Name: string (nullable = true)
#  |-- Vendor Number: integer (nullable = true)
#  |-- Item Number: integer (nullable = true)
#  |-- Item Description: string (nullable = true)
#  |-- Bottle Volume (ml): integer (nullable = true)
#  |-- State Bottle Cost: string (nullable = true)
#  |-- State Bottle Retail: string (nullable = true)
#  |-- Bottles Sold: integer (nullable = true)
#  |-- Sale (Dollars): string (nullable = true)
#  |-- Volume Sold (Liters): double (nullable = true)
#  |-- Volume Sold (Gallons): double (nullable = true)

# %%
# Register this DataFrame as a table.
tripsSql.registerTempTable("tripsSql")

# %%
data = sqlContext.sql("""
SELECT `Bottle Volume (ml)`, `Bottles Sold` FROM tripsSql
""")

print data.rdd.map(lambda p: p)
# Out:
# PythonRDD[95] at RDD at PythonRDD.scala:48

# %%
from pyspark.mllib.regression import LabeledPoint, LinearRegressionWithSGD, LinearRegressionModel

def parsePoint(line):
    values = [float(x) for x in line]
    return LabeledPoint(values[0], values[1:])

parsedData = data.rdd.map(parsePoint)

# Build the model
model = LinearRegressionWithSGD.train(parsedData, iterations=100, step=0.00000001)

# %%
# Evaluate the model on training data
valuesAndPreds = parsedData.map(lambda p: (p.label, model.predict(p.features)))
MSE = valuesAndPreds \
    .map(lambda (v, p): (v - p)**2) \
    .reduce(lambda x, y: x + y) / valuesAndPreds.count()
print("Mean Squared Error = " + str(MSE))
# Out:
# Mean Squared Error = 1098443.76554

# %%
lines = sc.textFile("../../../1.1-intro_to_big_data/code/5000.txt.utf-8.txt")
pairs = lines.map(lambda s: (s, 1))
counts = pairs.reduceByKey(lambda a, b: a + b)

# %%
counts.collect()
# Out:
# [(u'', 6954),
#  (u'vision) which dilates with distance and embraces with true', 1),
#  (u"painters Filippino Lippi and Lorenzo di Credi. L. di Credi's", 1),
#  (u'The canal which may be 16 braccia wide at the bottom and 20 at the', 1),
#  (u'the chief of the others. Of this then only we will speak, and the', 1),
#  (u'(_lumen cinereum_). His observations however, having hitherto', 1),
#  (u'1154.', 1),
#  (u'able, that your Highness will write a letter to the said Ser', 1),
#  (u'from the other. By a pyramid of lines I mean those which start from', 1),
#  (u'792.', 1),
#  (u'space, because as white has no colour of its own, it is tinged and', 1),
#  (u'the quarter where the sun is, and if you have your back turned to', 1),
#  (u'ocean.', 1),
#  (u'in the sciences of Anatomy and Physiology, will never be appreciated', 1),
#  (u'images are transmitted to the eye and will all be comprised within', 1),
#  (u'which is heavier.', 1),
#  (u'IX.', 2),
#  (u'all allusion to it in the MSS. Therefore, when I presently add a few', 1),
#  (u'method, but you must use this mirror always in the same month, and', 1),
#  (u'here and there it is not difficult to see how one theme suggested', 1),
#  (u'on the distance from the light (150--152).--On the proportion of', 1),
#  (u'white, large and hard.', 1),
#  (u'enduring life and beauty.', 1),
#  (u'598.', 1),
#  (u'chamber, according to a law which is more fully explained in 75?81.', 1),
#  (u'lowly moved across the luminous body, and the shadow is intercepted', 1),
#  (u'reproduced on Pl. CVIII, No. 4; a skull with indications of the', 1),
#  (u'infinite images of itself; and these, by infinite pyramids diffused', 1),
#  (u'always covered with snow; marmots (?) are found there.', 1),
#  (u'And for the slab of the tombstone 4 br. io in. long, 2 br. 4 1/2 in.', 1),
#  (u'each story, or two small orders on one story, in combination with', 1),
#  (u'flow; and do not let the nude forms be broken by too many details', 1),
#  (u'The youth should first learn perspective, then the proportions of', 1),
#  (u'fol., Firenze 1513, 8vo.) and by CESARIANO (Como 1521).]', 1),
#  (u'To make the great canal, first make the smaller one and conduct into', 1),
#  (u'chests and others on wheelbarrows. The man who carries it on his', 1),
#  (u'done me the favour to communicate to me, we get a more accurate view', 1),
#  (u'the lines have been preserved, the leaf being torn down the middle.', 1),
#  (u'and thorough research, do not however, as has been said, afford', 1),
#  (u'Girolamo da Cusano,who has in his keeping the deed of this gift; and', 1),
#  (u'No. 988. l. 38.]', 1),
#  (u'the "(Lo)cra" (both are given in the text farther on). There can', 1),
#  (u'to carry into effect with due love and care the task for which you', 1),
#  (u'in which we find this cipher employed; we may therefore conclude', 1),
#  (u'shadow from the other side, but where they intersect no light falls,', 1),
#  (u'eye, you must do it according to the diagram figured below. Let _m', 1),
#  (u'off; lines 11 and fol. are written in the margin.].', 1),
#  (u'drawn of their proper size, and if you see them from a distance they', 1),
#  (u"d'uomini._' See No. 608, 1. 19.]", 1),
#  (u'679.', 1),
#  (u'transmit its image to the eye _s_ as it has to strike the end _r_', 1),
#  (u'nearer to the eye these pyramids are intersected the smaller will', 1),
#  (u'they are the fullest, but more especially with a view to', 1),
#  (u'insensible bleeding of the capillary veins; and as one single body', 1),
#  (u'the thicker air nothing at all. This is when the movement of the', 1),
#  (u'mountains of Sarmatia in Asia and on those in Europe; so that the', 1),
#  (u'waters flow.', 1),
#  (u'you will see that men are selected to be doctors for diseases they', 1),
#  (u'HOW TO PROGNOSTICATE THE CAUSES OF CRACKS IN ANY SORT OF WALL.', 1),
#  (u'wine                S  6 d 4', 1),
#  (u'27.', 1),
#  (u'enter, and wear it away on the opposite side, bending the river in', 1),
#  (u"che egli, abile narratore com'era, si fosse proposto di scrivere una", 1),
#  (u'water in the eddies revolves more swiftly in proportion as it is', 1),
#  (u'this can scarcely be taken as evidence against my view that Leonardo', 1),
#  (u'good works and obey them.)', 1),
#  (u'The angle _c_ receives the highest grade of light because it is', 1),
#  (u'of sight, and the other the source of light; and make this as', 1),
#  (u'g_ will be equal to _g h_. And _m p_ will go into _h p_ as often as', 1),
#  (u'its fruit to the passers by, and every one cast stones at it.', 1),
#  (u'My Lord the love which your Excellency has always shown me and the', 1),
#  (u'[Footnote: In both these diagrams _A_ stands for _lume_ (light) _B_', 1),
#  (u'whole of that valley above for a distance of 40 miles in length.', 1),
#  (u'inasmuch as the two lights do not fall there, we say that the shadow', 1),
#  (u'It is of necessity that there should be more water than land, and', 1),
#  (u'To speak well of a base man is much the same as speaking ill of a', 1),
#  (u'nature.', 2),
#  (u'of the church of Santo Spirito[Footnote 1: See Pl. XCIV, No. 2. Then', 1),
#  (u'Supposing the earth at our antipodes which supports the ocean were', 1),
#  (u'Verrocchio entered in the_ "Libro degli Uffiziali di notte e de\'', 1),
#  (u'if all the mass of the earth were to be turned into salt, it would', 1),
#  (u'they were not designed for any particular monument, but were', 1),
#  (u'each other with many artifices deceptions and treasons. O monstrous', 1),
#  (u'Work of ... of the stable of Galeazzo; by the road of Brera', 1),
#  (u'many do, that is to say if you make a foundation of equal width from', 1),
#  (u'and who will die unburied, with their bones strewn in various parts', 1),
#  (u'the miserable state in which I find myself; and this is, that during', 1),
#  (u'pressed for oil and from which the oil has been extracted.', 1),
#  (u'measurements, of which there is no description in the MS. These are', 1),
#  (u'WHY OBJECTS WHICH ARE HIGH UP AND AT A DISTANCE ARE DARKER THAN THE', 1),
#  (u'to West and from North to South; and carry, by means of the air,', 1),
#  (u'to publish his MSS. (1).--The preparation of the MSS. for', 1),
#  (u'[Footnote: The first three lines are unfortunately very obscure.]', 1),
#  (u'The watery element was left enclosed between the raised banks of the', 1),
#  (u'proportion as they lie to the East.', 1),
#  (u'The sorest misfortune is when your views are in advance of your', 1),
#  (u'Different sorts of derived shadows (160-162).', 1),
#  (u'Of various colours which are none of them blue that which at a great', 1),
#  (u'OF THE NATURAL POINT.', 1),
#  (u'small furnace ... seed of lilies and of... Sell the boards of the', 1),
#  (u'tops of the mountains which bound it, but only so much rises as the', 1),
#  (u'1499.', 1),
#  (u'_a n o f_ are equal to the mouth.', 1),
#  (u'rising at the Eastern end of the Mediterranean sea must there begin', 1),
#  (u'[Footnote: In the original sketch, inside the circle in the first', 1),
#  (u'in the original, before lines 7-11. At the spots marked _B_ Leonardo', 1),
#  (u'represented in it, among which is the image of the second mirror,', 1),
#  (u'that he has a powerful and rich master; and if they discover no such', 1),
#  (u'remained unknown to astronomers, Moestlin and Kepler have been', 1),
#  (u'a multitude of men to the destruction of their lives.', 1),
#  (u'colour." The other replied: "It often happens, but you have not', 1),
#  (u'Trivulzio died at Chartres in 1518, only five months before', 1),
#  (u'done, I should have my rights. Afterwards hearing that the canal was', 1),
#  (u'avec le temps faits en voute a cholli_.]', 1),
#  (u"sicuro luogo, cioe nell'ultima arcata della nave di mezzo della", 1),
#  (u'Of the horse I will say nothing because I know the times. [Footnote:', 1),
#  (u'from MS. E, written in 1513--14, sufficiently prove that Leonardo did', 1),
#  (u'That side of an object in light and shade which is towards the light', 1),
#  (u'will..... Where one river by reason of its low level cannot flow', 1),
#  (u'Aristotle says that if a force can move a body a given distance in a', 1),
#  (u'joints, and consequently they settle less; and this cannot happen if', 1),
#  (u'[Footnote: This note is written inside the sketch of a plan of a', 1),
#  (u'Syphon. See Vol. I, Pl. XXIV, No. 1.]. And at all times the water', 1),
#  (u'the spots where nature must necessarily produce them. The sculptor', 1),
#  (u'Darkness affects every thing with its hue, and the more an object', 1),
#  (u'into 6 parts and one of these parts will be its thickness at the', 1),
#  (u'three senses: sight, hearing and smell cannot well be prevented;', 1),
#  (u'Sadness resembles the raven, which, when it sees its young ones born', 1),
#  (u'evidence as to when this note may have been written beyond the', 1),
#  (u'It seems to me that men of coarse and clumsy habits and of small', 1),
#  (u'which sees this reflection on the surface of the water occupying the', 1),
#  (u'_Astronomy_.', 1),
#  (u'the beauty of the sun and sky. And not content with so much evil,', 1),
#  (u'268.', 1),
#  (u'the central ray is less overcome by false rays; because the lines', 1),
#  (u'The painter must always study on the wall on which he is to picture', 1),
#  (u'horizon it is not blue but rather between smoke and dust colour.', 1),
#  (u'disparage the Ancients, who were the originators of grammar and the', 1),
#  (u'Necessity has provided that all the images of objects in front of', 1),
#  (u'regiae gentis." _See_ Le Madracen, Rapport fait par M. le Grand', 1),
#  (u'when the weather is calm, settles and becomes solid at the bottom of', 1),
#  (u'mountains, and these, finding some fissure, issue continuously and', 1),
#  (u'tinged the cloud with its own hue. And this cloud attracted to it', 1),
#  (u'inadvertence by apparent difficulties in the sense or connection of', 1),
#  (u'[Footnote: Compare No. 837, 11. 54-57, No. 1296 (p. 363 and 364),', 1),
#  (u'the other borrowed. Original light is that which is inherent in the', 1),
#  (u'their contents remained a mystery, can only be accounted for by the', 1),
#  (u'higher.', 1),
#  (u'circumstances of the story. Thirdly, whether the figures are', 1),
#  (u'in one centre and in one single spot; on the contrary it would have', 1),
#  (u'Round the base on which the horse stands there are 8 figures at 25', 1),
#  (u'des bastiments, ediffices et reparacions que le dit seigneur fait', 1),
#  (u'must give it such abutments as can resist the thrust; and you can do', 1),
#  (u'          no expense into plain ASCII, EBCDIC or equivalent', 1),
#  (u'breadth, and in proportion as their height is greater than their', 1),
#  (u'_f_. brain', 1),
#  (u'(Of Asses that are beaten.)', 1),
#  (u"1472, _secondo Morelli e Dibdin, ecc._ (G. D'A.)] Burchiello,", 1),
#  (u'should be a thick and shady wood; the waters at the top of the', 1),
#  (u'having placed myself--such a small patch of snow--in so lofty a', 1),
#  (u'transmitted to its under side. [Footnote: See Pl. XXVIII, No. 2, the', 1),
#  (u'many and which sinews cause it; and which muscle, by swelling,', 1),
#  (u'really has, it would have weight, and having weight, that it could', 1),
#  (u'24 tavole make 1 perch. 4 trabochi make 1 tavola. 4 braccia and a', 1),
#  (u'1084.]', 1),
#  (u"the 'Ars poetica' of Horace [5].", 1),
#  (u'prospettiva di Bramantino). La prima prospettiva fa le cose di', 1),
#  (u'     [*]  The eBook, when displayed, is clearly readable, and', 1),
#  (u'umberless bright particles conceal the stars; and if it were not', 1),
#  (u'all that portion of it which is exposed to the sun and atmosphere', 1),
#  (u'white, there will be little difference of light. If it is lighted by', 1),
#  (u'yellow and a little green and occasionally some lake; for the', 1),
#  (u'938).', 1),
#  (u"decade, [6] Ciecho d'Ascoli, The fourth decade, [7] Albertus Magnus,", 1),
#  (u'over again with the pen in the His de la Salle collection also in', 1),
#  (u'2 small bowls,', 1),
#  (u'The seat of the common sense.', 1),
#  (u'third of its volume to make up the amount of the square mile of the', 1),
#  (u'the lines between them; extending from the centre of the luminous', 1),
#  (u'differs from that of M. RAVAISSON or to justify myself, since they', 1),
#  (u'drying one after the other, it makes itself three or four coatings', 1),
#  (u'The trees, when you place yourself between them and the sun, will', 1),
#  (u'wine         S 12 d', 1),
#  (u'actually and obviously are? If Leonardo had been a man of our own', 1),
#  (u'seems to represent an unravelled plait or tissue.]', 1),
#  (u'have brought them on to a very good end; nothing else occurs to me.', 1),
#  (u'to note calling them 1st, 2nd, 3rd, 4th, 5th; and has affixed a name', 1),
#  (u'Again, this fire, stuck at the top of a long plank which has one', 1),
#  (u'mentioned in line 43.]', 1),
#  (u'is at its meridian, its shadow extends as far as the borders of', 1),
#  (u'body and by which every injury is repaired, also moves the waters', 1),
#  (u'The upper side of their leaves is turned towards the sky that it may', 1),
#  (u"the same idea as we find in some of Leonardo's designs for the", 1),
#  (u'PREFACE.', 1),
#  (u'voluminous MS. as the former one and it is possible that they are', 1),
#  (u'The ant found a grain of millet. The seed feeling itself taken', 1),
#  (u'hart@pobox.com', 1),
#  (u'to the very same natural laws. For it will easily be understood that', 1),
#  (u'and pulling off the ripe fruits, which he put into his open mouth', 1),
#  (u'believed that all the water of the ocean has passed very many times', 1),
#  (u'The simple derived shadow is of two kinds: one kind which has its', 1),
#  (u'it so that the limbs which come in front of the nearer figures may', 1),
#  (u"might feel tempted to take it as a study by Bramante for St. Peter's", 1),
#  (u'_As an application of these studies the plan of a semicircular vault', 1),
#  (u'their colours (435).--The proportions of light and shade in trees', 1),
#  (u'then erased, _e accaduto un nuovo accidente_. From the sequel this', 1),
#  (u'718.', 1),
#  (u'Darkness, then, is the strongest degree of shadow and light is its', 1),
#  (u'_The memoranda collected at the end (No. 1505--1565) are, in the', 1),
#  (u'The figures which are seen against the fire look dark in the glare', 1),
#  (u'more ready and more swift in her creating, than time in his', 1),
#  (u'mastering the text. Leonardo made use of an orthography peculiar to', 1),
#  (u"1. A drawing in silver point on brown toned paper of a woman's head", 1),
#  (u'But you who live in dreams are better pleased by the sophistical', 1),
#  (u'cloak. And those limbs which you allow to be seen you must make', 1),
#  (u'(Of the Dead which are carried to be buried.)', 1),
#  (u'which they are illuminated, that shadow will be the longest of the', 1),
#  (u'lower side, while the sun shines on the upper side and as they are', 1),
#  (u'note_ "Absoluti cum condizione ut retamburentur" (Tamburini _was the', 1),
#  (u'enough to crush him.', 1),
#  (u'South East and East at a distance of 20 miles from Imola and ten', 1),
#  (u'Item. He desires and orders that the said Messer Francesco de Melzo', 1),
#  (u"By pointing out the analogies between Leonardo's architecture and", 1),
#  (u'manners, and though in Lombardy there is no building by him in his', 1),
#  (u'there remain 26 lire 6 soldi.', 1),
#  (u'faces and is faced by the original source of these rays, and no', 1),
#  (u"Salai's cloak, the 4th of April 1497.", 1),
#  (u'assuming that Leonardo means 1489". In the elaborate catalogue of', 1),
#  (u'the eyebrows. And, in the same way, in profile the distance from the', 1),
#  (u'erection._', 1),
#  (u'commonly supposed to be identical with that described and lauded by', 1),
#  (u'and be shifted as necessity demands for the changes of its centre of', 1),
#  (u'You may distribute copies of this eBook electronically, or by', 1),
#  (u'whether Epicurus was [right in] saying that the sun was only as', 1),
#  (u'derived shadow but only by the body casting the shadow; &c. If a', 1),
#  (u'and left for the distance of 20 miles throughout of the same nature.', 1),
#  (u'lights fell on the point of intersection, the shadows would be', 1),
#  (u'745.', 1),
#  (u'not bring thee to Fame; nor staying beneath the quilts. He who,', 1),
#  (u'1200.', 1),
#  (u'with it are grouped all its tributaries, which at first fell into', 1),
#  (u'Benedetto 4,', 1),
#  (u'THE CAMELEON.', 1),
#  (u'The colours of the rainbow are not produced by the sun, for they', 1),
#  (u'dans le manuscrit, des renvois_."] The greatest force a man can', 1),
#  (u"to impugn the logical connection of the author's ideas in his MS.;", 1),
#  (u'HOW THERE ARE 2 KINDS OF LIGHT, ONE SEPARABLE FROM, AND THE OTHER', 1),
#  (u"occupying only a small space in the needle's eye how can you", 1),
#  (u'suggests the curve of Sta Maria del Fiore (Pl. LXXXVIII No. 5; Pl.', 1),
#  (u'CONSTANCY.', 1),
#  (u'should bear relation to the direction of this principal line.', 1),
#  (u'Supposing that a poet applies himself to represent beauty, ferocity,', 1),
#  (u'lost it is round.', 1),
#  (u'and 11 as well as the circle above the text on Pl. XXXI, are in a', 1),
#  (u'uniform colour, this uniformity will vary according to the variety', 1),
#  (u'come prigionieri di stato; e fra questi Messer Francesco Visconti, e', 1),
#  (u'and the roots of the hair _a b_; and equal to five sixths of the', 1),
#  (u'ancle of the left foot. And the left shoulder will be in a', 1),
#  (u'machines most efficient for offence and defence; and vessels which', 1),
#  (u'given to it solely because it is the common judge of all the other', 1),
#  (u'the subject of an episode which probably had ended in failure and', 1),
#  (u'that every object sends its image to the eye by a pyramid of lines;', 1),
#  (u'glowing red. And this glow will diminish in proportion as it is', 1),
#  (u'[Footnote: Between lines 1 and 2 there is in the original a large', 1),
#  (u'nature of incandescent stone, and the one who opposed him as to that', 1),
#  (u'[Footnote: 5--6. This passage is so obscure that it would be rash to', 1),
#  (u'when you return home work out these notes in a complete form. The', 1),
#  (u'not wait for my payment beyond the time, when my works are finished.', 1),
#  (u'greater length than before. As is shown in the example; _d c e_ will', 1),
#  (u'ancient chapel San Satiro, via del Falcone, Milan, is a specimen of', 1),
#  (u'I say that first you ought to learn the limbs and their mechanism,', 1),
#  (u'(503--506).--Useful games and exercises (507. 508).--II. THE', 1),
#  (u'seems to me however to be the work of some unknown Florentine', 1),
#  (u'_f g_ is the fourth part of a man and is equal to _g h_ and measures', 1),
#  (u'in the Vatican, and it may be safely inferred from No. 1352 l. 2,', 1),
#  (u'know that dog to be well fed, they respect him, because they judge', 1),
#  (u'Cesare Borgia is probably meant. After being made Archbishop of', 1),
#  (u'seems already indicated by the diagonal lines in the plans Pl. LXXXV', 1),
#  (u'744.]. The river may be dammed up at such a height that the waters', 1),
#  (u"peacock's eyes, and this holds good for all the housings of the", 1),
#  (u'1046.', 1),
#  (u'1._opero allor [?] bo [alloro?]_ = "_ou bien de [laurier]_."', 1),
#  (u'kidts-kin parchment, well oiled and dried. And when you have used it', 1),
#  (u' 3000  2001 November', 1),
#  (u'horse. In all its other parts it is like a bull, excepting that its', 1),
#  (u'confused outlines to the derived shadow than a spherical light, and', 1),
#  (u'dust will tend to its colour. This mixture of air, smoke and dust', 1),
#  (u'human matters in telling of one supreme wickedness, which does not', 1),
#  (u'moisture that made the mortar soft evaporates.', 1),
#  (u'462.', 1),
#  (u'374.', 1),
#  (u'up courage.', 1),
#  (u'and weak or small and weak?', 1),
#  (u'The tremendous fury of the wind driven by the falling in of the', 1),
#  (u'parrot in moving among boughs never puts its feet excepting where it', 1),
#  (u'live with me in the house, and agreed with me that I should charge', 1),
#  (u'bricks, and make a great fire therein. When it is quite red hot give', 1),
#  (u'funnels, narrow at the top and wide over the manger, in order that', 1),
#  (u'hand, pointing" which, on the other hand, I regard as a copy by a', 1),
#  (u'When the sun is covered by clouds, objects are less conspicuous,', 1),
#  (u'him a carlino a day.', 1),
#  (u'filled up by the tree _d_, and part of the tree _d_ is filled up by', 1),
#  (u'body of the earth, corresponding to the sources of rivers, which are', 1),
#  (u'at all. The grades of depth in compound shadows are fewer in', 1),
#  (u'because it is a mathematical line which originates from a', 1),
#  (u'Hold the hoofs in the tongs, and cast them with fish glue. Weigh the', 1),
#  (u'consequently built up of numerous separate researches, and it is', 1),
#  (u'As to whether it is better that the water should all be raised in a', 1),
#  (u'8 _piedi_ in line 25. There are other deviations of less importance', 1),
#  (u'[Footnote: See Pl. XXVII, No. 5.]', 1),
#  (u'about them has hitherto been made public. The limits of my plan in', 1),
#  (u'radiate which are sent forth by the surface of the luminous body and', 1),
#  (u'This is proved by the 7th of this which says: The opposite ends of', 1),
#  (u'in ordinary braccia; but if the braccia are those used in measuring', 1),
#  (u'which the details have almost disappeared in the original but have', 1),
#  (u'number of other movements always effected by two tendons; one tendon', 1),
#  (u'The red chalk drawing reproduced on Pl. XLVI is in the Accademia at', 1),
#  (u'that is the ornaments, to the taste of the sculptors. But to return', 1),
#  (u'rather than rapidity.', 1),
#  (u'sending a request within 30 days of receiving it to the person', 1),
#  (u'1453.', 1),
#  (u'three lines of the text belonging to it are written above the sketch', 1),
#  (u'the original blocks of these are preserved in his department in the', 1),
#  (u'Florence to Fucechio it is 40 miles by the river Arno.', 1),
#  (u'means of mere abstract value, but, being deduced, as he says, from', 1),
#  (u'The shadow caused by the light _e_, which is yellow, has a blue', 1),
#  (u'it draws in its breath so strongly that it draws the birds into its', 1),
#  (u'And the eye can best distinguish the forms of objects when it is', 1),
#  (u'charge. It was in fact repeated, two months later, and on this', 1),
#  (u'Many things that have been before that time destroyed by fire will', 1),
#  (u'tone, and wherever the trees or branches are thickest they will be', 1),
#  (u'Let _s_ be the light, and _r_ the eye, _c d n_ the first tree, _a b', 1),
#  (u'adversary were to say that in infinite time the sea would dry up or', 1),
#  (u'separated, or rise from the centre of the building and therefore', 1),
#  (u'1039.', 1),
#  (u'red for drawing in silver point, but has not been used for that', 1),
#  (u'human figure[Footnote 35: Compare Pl. CVII. The original drawing at', 1),
#  (u'bread S.. d', 1),
#  (u'As to men and horses represented in battle, their different parts', 1),
#  (u'solution of a geometrical problem) have no reference to the picture', 1),
#  (u'TO DRAW A FIGURE ON A WALL 12 BRACCIA HIGH WHICH SHALL LOOK 24', 1),
#  (u'disunites itself, and its nature is modified, by which that nature', 1),
#  (u'pavilion in the garden of the duke of Milan, and two churches,', 1),
#  (u'_XIII.', 1),
#  (u'their pictures fail in that relief and vividness which objects have', 1),
#  (u'PROOF.', 1),
#  (u'1222.', 1),
#  (u'such truths as are in his favour; and if we go on to the rest he', 1),
#  (u'constructed and enlarged by him.', 1),
#  (u'But if these same colours are situated in a well-lighted place, they', 1),
#  (u'might therefore be classed after this group. [Footnote 1: This plan', 1),
#  (u'did not enter into possession, because at that time when it was', 1),
#  (u'721.', 1),
#  (u'Item.', 1),
#  (u'The tongue is found to have 24 muscles which correspond to the six', 1),
#  (u'Magnificence the President to what end the regulation of the water', 1),
#  (u'gave to this same de Vinci, the stream of the canal of Santo', 1),
#  (u'in question is that originally intended by Leonardo; but their', 1),
#  (u'1057.', 1),
#  (u'a note as follows (_Histoire des sciences mathematiques en Italie', 1),
#  (u'rare moving through the rare with only moderate swiftness, like a', 1),
#  (u'against fresh is proved by a thin cloth dry and old, hanging with', 1),
#  (u'the coins round. Hence it passes only through the hands of the', 1),
#  (u'The relative proportions of the torso and of the foot.', 1),
#  (u'above the plains of Italy, where now birds fly in flocks, fish were', 1),
#  (u'The shells, oysters, and other similar animals, which originate in', 1),
#  (u'monument at Padua: "Egli [Donatello] vi ando ben volentieri, e fece', 1),
#  (u'because: if you see a man close to you, you discern the exact', 1),
#  (u'vertical glass plane (83--85.)--The angle of sight varies with the', 1),
#  (u'on Pl. LXXXVII, No. 2.]', 1),
#  (u'properties of a line, and not of a surface. And as the line, having', 1),
#  (u'space between the outer corner of the eye and the opening of the', 1),
#  (u'itself, for the love it bears to fair maidens forgets its ferocity', 1),
#  (u'entries in lines 3 and 4 refer to the payments of Jacopo Tedesco,', 1),
#  (u'the shoulders and 3 times into the face, and four times into the', 1),
#  (u'power of its whole mass, it is evident that the farther its rays', 1),
#  (u'Therefore, _b_ being farthest from _a_ and _c_ in the fold _a b c_', 1),
#  (u'If you want to build an armada for the sea employ these ships to ram', 1),
#  (u'letter. The meaning is obscure.]', 1),
#  (u'same sheet._', 1),
#  (u'four principal chapels the type Pl. LXXXVIII No. 3, as we have', 1),
#  (u'And if you say: "I will withdraw so far that their words cannot', 1),
#  (u'object in light and shade which sends not its shadow but the image', 1),
#  (u'that is where the chin ends and passes into the lower lip of the', 1),
#  (u'threads; and thus you can represent them, one over another as nature', 1),
#  (u'undistinguishable gradation and form, as is shown in the 3rd', 1),
#  (u'being unable to provide their own food, are necessarily dependent on', 1),
#  (u'particular light, and another thing if it is in a light place with', 1),
#  (u'so forth (No._ 920, _Books_ 10, 11 _and_ 12_); but those passages in', 1),
#  (u'_The following texts refer to the construction of palaces and other', 1),
#  (u'some details of pillars; on Pl. CI No. 3 slender pillars designed', 1),
#  (u'colour in leaves (430--434).--A classification of trees according to', 1),
#  (u'in uso) e con tal leggiadria gli dipinse una mano ecc._ The incident', 1),
#  (u"partie du chateau, connue sous le nom d'aile de Francois I, et dont", 1),
#  (u'support for the spectacles,--[Footnote 11: San Gallo; possibly', 1),
#  (u'Let _a_ be the sun, and _n m_ the ruffled water, _b_ the image of', 1),
#  (u'176.', 1),
#  (u'than a selection of extracts which I have made from the originals at', 1),
#  (u'move if the body nearest to the window is put in transverse motion', 1),
#  (u'inventions. And this is, when you look at a wall spotted with', 1),
#  (u'light is nearer to the said body than the other on the opposite', 1),
#  (u'atmosphere do not produce a reflection verging on blue, inasmuch as', 1),
#  (u'threatening others with metal and fire which will do no harm at all', 1),
#  (u'therefore be referred to in this place. In line 62 we read therefore', 1),
#  (u'illuminates it; and of the colour of the atmosphere which lies', 1),
#  (u'passare l\'alteza - di - 2 - quadri" _(neither of the 9 domes must', 1),
#  (u'Melzi or Mazenta is comparatively unimportant. There are in the', 1),
#  (u'against each other with the greatest loss and frequent deaths on', 1),
#  (u'[Footnote 81: Compare No. 945.] Something will fall from the sky', 1),
#  (u'because where there is no body, there is a vacuum; and no vacuum can', 1),
#  (u'In the West, near to Flanders, the sea rises and decreases every 6', 1),
#  (u'but what is like itself, that is, lies; this does not happen in', 1),
#  (u'known; he was of the same age as Leonardo. Further details will be', 1),
#  (u'attenente alla prospettiva, le quali ho voluto riferire, e quasi', 1),
#  (u'edge and the light at the point _o_.', 1),
#  (u'whose impetus moves them across other eddies going in a contrary', 1),
#  (u'was enabled, by the liberality of Lord Ashburnham, to inspect his', 1),
#  (u'Francesco di Giorgio and perhaps also Bramante. But, on the other', 1),
#  (u'objects appear in relief, you, who have in your colours far stronger', 1),
#  (u'WEAK; AND THE SAME AS TO COLUMNS.', 1),
#  (u'TO PROVE HOW IT IS THAT LUMINOUS BODIES APPEAR LARGER, AT A', 1),
#  (u'the atmosphere.', 1),
#  (u'of them give a satisfactory meaning.]', 1),
#  (u'871.', 1),
#  (u'earth).]', 1),
#  (u'154.', 1),
#  (u'69.', 1),
#  (u'larger, rises the dome_ c d. _The aisles above and below thus', 1),
#  (u'DESCRIPTION OF THE DELUGE.', 1),
#  (u'1565.', 1),
#  (u'as that the sea then fulfils the same function to the dark side of', 1),
#  (u'There will come a time when no difference can be discerned between', 1),
#  (u'4. A silver-point study on greenish paper, for the head of John the', 1),
#  (u'sculpture is perhaps mythical. The various passages in praise of', 1),
#  (u'From the tip of the longest finger of the hand to the shoulder joint', 1),
#  (u'is forced to diminish in its remoter parts more than in its nearer', 1),
#  (u'Let _a b_ be the side where the primary shadow is, and _b c_ the', 1),
#  (u'this theory. The recognised, but extremely complicated science of', 1),
#  (u'Legat fit aux deux mecaniciens. Dans la meme annee, Aristote', 1),
#  (u'earthquakes, entitled _kechf aussalssaleb an auasf ezzel-zeleh_, and', 1),
#  (u'LIMITED WARRANTY; DISCLAIMER OF DAMAGES', 1),
#  (u'the surface of the sea. And if you should think that the moon,', 1),
#  (u'object which reflects it (to the eye) as gold or silver or the like.', 1),
#  (u'charged with the whole weight.', 1),
#  (u'is shown between the columns, and above the entablature is a plinth', 1),
#  (u'letter B, which precedes each name. It may be meant for _basa_', 1),
#  (u'proofs are opposed to the authority of certain men held in the', 1),
#  (u'less of the light _a o_, but by the accident [of distance] it is', 1),
#  (u'plane which is equally distant from the eye in every part. Complex', 1),
#  (u'561.', 1),
#  (u'he same thing happens with the above mentioned planets which,', 1),
#  (u'together and make your cast with it.', 1),
#  (u'1516.', 1),
#  (u'observations on the contents of most of the rare books here', 1),
#  (u'my small dimensions by no means merit this elevation. How easily may', 1),
#  (u'should then be equally justified in supposing some more of', 1),
#  (u'_What seems to confirm the supposition that the lifting up of a', 1),
#  (u'rays to pass; the effect of the shadow of the man cast by this', 1),
#  (u'Sculptured figures which appear in motion, will, in their standing', 1),
#  (u'round. Set a light close to it in such a position as that it shines', 1),
#  (u'is ever visible from any spot within the pyramid of pure derived', 1),
#  (u'The surface of every opaque body is affected by the colour of the', 1),
#  (u'light at different distances (182).--Further complications in the', 1),
#  (u'Monte Lupo and Capraia where the rocks, which are very large, are', 1),
#  (u'of depth in the mist; and sees the height of the middle tower _b_', 1),
#  (u'those of which the addresses can no longer be named. Still, as', 1),
#  (u'stair on a circular plan because the corners of square ones are', 1),
#  (u'cast out from human intestines." And it cried to Heaven, imploring', 1),
#  (u'is illuminated, as that... [Footnote 42: Here the text breaks off;', 1),
#  (u'fruits, such as nut-trees, fig-trees and the like, always droop', 1),
#  (u'point _a_, that weight tends to fall towards _b_, and the arch', 1),
#  (u'towards the West, illuminated by the sun after its setting the third', 1),
#  (u'_Such theoretical questions, as have been laid before the reader in', 1),
#  (u'nourishment, after having first drawn the tree of veins and nerves', 1),
#  (u'by the principles of light and shade on which it is based. The word_', 1),
#  (u'Happy will they be who lend ear to the words of the Dead. (Who read', 1),
#  (u'to the Latin cross in Pl. XCVII No. 3.', 1),
#  (u'betray his knowledge of refraction and of the inversion of the image', 1),
#  (u"[Footnote 1548 and 1549: On the same sheet is the text No. 1015 in Leonardo's own handwriting.]",
#   1),
#  (u'graceful you must make the limbs elegant and extended, and without', 1),
#  (u'ch. II, that the following note existed on the same leaf in MS. C.', 1),
#  (u'  Movement will cease before we are', 1),
#  (u'for which, O reader! do not blame me, for the subjects are many and', 1),
#  (u'(509).--On the construction of windows (510--512).--On the best', 1),
#  (u'seed according to the variety of the things she desires to produce', 1),
#  (u'inept, that after devoting itself to one single thing and doing it', 1),
#  (u'would mount on horseback, and go to his Lord and obtain such letters', 1),
#  (u'surrounding objects.', 2),
#  (u'Many will there be who will die a painful death by means of the', 1),
#  (u'1534.', 1),
#  (u'rays are seen passing through the surface of the air at a slanting', 1),
#  (u'925.', 1),
#  (u'--Guglielmo di Ser Martino,--Bartolomeo del Tovaglia,--Andrea', 1),
#  (u'the things included in them. And then you occupy yourself with', 1),
#  (u'chariot and with a branch of laurel in her hand, to signify the hope', 1),
#  (u'952.', 1),
#  (u'sky will be seen through a denser and whiter atmosphere, which will', 1),
#  (u'Constantinople. The dress is certainly not that in which he', 1),
#  (u'Pavia, or by Dolcebuono in the Monastero Maggiore at Milan (see Pl.', 1),
#  (u'coasts, but to a deluge of water which carried with it all the', 1),
#  (u"molte discussioni et dubii conclusesi che l'opera fussi molto al", 1),
#  (u'No small hole can so modify the convergence of rays of light as to', 1),
#  (u'A book of the lowest level which can be found in the current of the', 1),
#  (u'it will be wider there than anywhere else.', 1),
#  (u'25.', 1),
#  (u'aphoristic style, and I have transcribed them in exactly the order', 1),
#  (u'I teach you to preserve your health; and in this you will succed', 1),
#  (u'the pupil with the things seen by means of the light. And the pupil', 1),
#  (u'ends at the sea, and since in fact the dry land that is uncovered is', 1),
#  (u'WHAT SORT OF THING THE MOON IS.', 1),
#  (u'this animal, being killed by a catapult, measured 123 feet, that is', 1),
#  (u'troubled, is never so thirsty but that it will abstain from', 1),
#  (u'Oh! how many will they be that never come to the birth!', 1),
#  (u'the sun shines, and the shadows between these waves are small and', 1),
#  (u'Pl. VI, No. 3. In the diagram given above line 14 of the original,', 1),
#  (u'6. _fregalo bene con un panno_. He reads _pane_ for _panno_ and', 1),
#  (u'must pass through its walls and be secured beyond the walls with', 1),
#  (u'>From the beginning of the canal to the mill.', 1),
#  (u'arranging them on the method both of their natural order and of', 1),
#  (u'for concluding that this writing from left to right is spurious.', 1),
#  (u'alchune additione cavate del testo & istorie de la Bibia & del libro', 1),
#  (u'as we may see them on sea-shores every day. And if we find oysters', 1),
#  (u'rather than the human form, or a bundle of radishes rather than the', 1),
#  (u'number of lines which mingle or join those reaching it which come to', 1),
#  (u'Leonardo manages to combine gothic details and structure with the', 1),
#  (u'reproduced. It represents a hill of the same shape as that shown at', 1),
#  (u'The highest good is wisdom, the chief evil is suffering in the body.', 1),
#  (u'to give the appearance of a beam from within. Granite alone would be', 1),
#  (u'to it, are entirely effaced.]', 1),
#  (u'The derived shadows will be equal in depth if they are produced by', 1),
#  (u'_Only a very small selection from the mass of anatomical drawings', 1),
#  (u"are of practical importance to this day. Leonardo's theory as to the", 1),
#  (u'the trench were 16 braccia wide and 4 deep, coming to 4 lire for the', 1),
#  (u'placed towards the point in the eye there will be only pyramids', 1),
#  (u'the injuries to which the picture has been exposed than of the', 1),
#  (u'950.', 1),
#  (u'_On one point only can the collection of passages included under the', 1),
#  (u'this passage that the greater part of his Manuscripts were now', 1),
#  (u'original work itself. The wood-cut given on p. 344, is only intended', 1),
#  (u'illustrate it.]', 1),
#  (u'251.', 1),
#  (u'relief than in any other way; hence I would remind you O Painter! to', 1),
#  (u'the topographical notes, and for this reason it seemed that it would', 1),
#  (u'This I shall do at the end of the book. Then, in four drawings,', 1),
#  (u'look as he were dead; and these birds want to peck at his tongue,', 1),
#  (u'his half raised body. Others represent shouting with their mouths', 1),
#  (u'history affords instances of severe earthquakes at Rhodes, among', 1),
#  (u'When various objects are removed at equal distances farther from', 1),
#  (u'I reply that when there are neither nerves nor bones there can be no', 1),
#  (u'air, and the foam prevents you, you may draw a breath of the air', 1),
#  (u'The eye _f_ and the eye _t_ are one and the same thing; but the eye', 1),
#  (u'505.', 1),
#  (u'                            you ...', 1),
#  (u'out the practical precepts as to the representation of trees and', 1),
#  (u'O Earth! why dost thou not open and engulf them in the fissures of', 1),
#  (u'tola--ferro stagnato_ (tinned iron); _romantina_ is some special', 1),
#  (u'that in 1478 this painter was commissioned by order of the Signoria', 1),
#  (u'OF REVERBERATION.', 1),
#  (u'vertical plane which is the standard and guide of perspective. Let', 1),
#  (u'it all sorts of movable objects which are to be found in the earth,', 1),
#  (u'inwards as the adversary says.', 1),
#  (u'deluge afterwards rose with its waters above the mountains, the', 1),
#  (u'Which of these two cubes will shrink the more uniformly: the cube', 1),
#  (u'damaged the Romans in the siege of Syracuse, nevertheless did not', 1),
#  (u'thoroughly pulverised; then wash it with aqua fortis, and the', 1),
#  (u'The edges of the images, of whatever colour, which are transmitted', 1),
#  (u'the arch _a_, _b_, _f_. I say that, by the foregoing, as the', 1),
#  (u'That portion of a tree which is farthest from the force which', 1),
#  (u'such as I am." And so it was.', 1),
#  (u'of Northern Italy acquainted with the place here described. Hardly', 1),
#  (u'cut out about 9 centimetres by 7 and a blank piece has been gummed', 1),
#  (u'let it dash along and lay bare the twisted and gnarled roots of', 1),
#  (u'_x y_ is not the base of a square, but is equal to half the space', 1),
#  (u"Timbal's picture and in the other finished copies. An old copy of", 1),
#  (u'each other. The sides of images which pass through openings into a', 1),
#  (u'the Carnival at Florence in 1513. See VASARI VI, 251, ed. MILANESI', 1),
#  (u'the columns touch; and beyond where they touch they cover each', 1),
#  (u'not find that the sand mixed with seaweed has been petrified,', 1),
#  (u'A man, seeing a woman ready to hold up the target for a jousting', 1),
#  (u'help of various machines answering the same end, it will never', 1),
#  (u'[Footnote: An indistinct sketch, accompanies this passage.]', 1),
#  (u"_Leonardo's two drawings, preserved in the museum at Buda-Pesth and", 1),
#  (u'inventors but vaunters and declaimers of the works of others--be', 1),
#  (u'grammarians of about the fourth century A. D. Early publications of', 1),
#  (u'1464.', 1),
#  (u'the pilasters, one ounce of blue 10 soldi', 1),
#  (u'wide 36 hundredweight....... duc. 36.', 1),
#  (u'slimmer and long bodied; and it is all white and marked with black', 1),
#  (u'the depth only the first bank will be increased, that is 4 braccia', 1),
#  (u'There will be great winds by reason of which things of the East will', 1),
#  (u'30 braccia wide on each side; the lower entrance leads into a hall', 1),
#  (u'be seen or recognised by the eye. Light is totally contrary and', 1),
#  (u'laid his sword in the scale when the tribute was weighed.]', 1),
#  (u'The razor having one day come forth from the handle which serves as', 1),
#  (u'scientific labours, Leonardo devotes here a good deal of attention', 1),
#  (u'thing.', 1),
#  (u'order not to be frightened by the spears she keeps her eyes on the', 1),
#  (u'jealousy and greediness it devoured it, having reduced it almost to', 1),
#  (u'Instrumental or mechanical science is of all the noblest and the', 1),
#  (u'itself, is not very strong, and besides this some reflected lights', 1),
#  (u"writings collected in this section, the transcript of Leonardo's", 1),
#  (u'1307.', 1),
#  (u'follow the demonstration of the first three figures of the bones,', 1),
#  (u'The earth that is dug out from the cellars must be raised on one', 1),
#  (u'imperatore, esso fu collocato sotto un arco trionfale davanti al', 1),
#  (u'side of the moon which is never seen. [Footnote: Compare also Vol.', 1),
#  (u'thickness of the metal in clay.]', 1),
#  (u'be seen in each curve of the waves of the sea; and as in these many', 1),
#  (u'candles             S  3 d', 1),
#  (u'(334).--The relative proportions of the torso and of the leg (335.', 1),
#  (u'WHY DOGS TAKE PLEASURE IN SMELLING AT EACH OTHER.', 1),
#  (u'pass there.', 1),
#  (u'OF LIGHT AND SHADOW IN A TOWN.', 1),
#  (u'clouds, which does not happen twice in an age, an enormous mass of', 1),
#  (u'same colour. And the veins, which discharge this blood, are not', 1),
#  (u'Every body in light and shade is situated between 2 pyramids one', 1),
#  (u'collection of his manuscripts in the Institut de France, and some of', 1),
#  (u'and I have actually arranged the texts in accordance with the clue', 1),
#  (u'themselves by their strong sense of hearing and of smell, which are', 1),
#  (u'not be true.', 1),
#  (u'time, we might perhaps have attempted to account for the facts by', 1),
#  (u'longer has darkness beyond it, but this bright and luminous space.', 1),
#  (u'jerkin of... and skins, to make new ones; the lake of Alessandro.', 1),
#  (u'_goba, arnigasar, caruda_, names most likely of different peaks. Pl.', 1),
#  (u'be seen in the beginning of No._ 295. _Attempts have been made to', 1),
#  (u'leanness ever diminishes it?', 1),
#  (u'Among objects of equal size, that which is most remote from the eye', 1),
#  (u'lies precisely between the past and the future, and has nothing in', 1),
#  (u'cosa voleva provare._', 1),
#  (u'742) gives a partial view of the town, with its streets and houses,', 1),
#  (u"The beginning of Leonardo's literary labours dates from about his", 1),
#  (u'By a pyramid of lines I understand those lines which start from the', 1),
#  (u'the cathedral of Florence, and with similar round windows in its', 1),
#  (u'renders the meaning of the passage as I think it must be understood.', 1),
#  (u'  Saint Clara with the tabernacle,', 1),
#  (u'That part of a tree which has shadow for background, is all of one', 1),
#  (u'capable man,--[33] and you may believe me,--except Leonardo the', 1),
#  (u'On the luminosity of the Earth in the universal space (874-878).', 1),
#  (u'rise, and small, when they are on the meridian. Let _a_ be the earth', 1),
#  (u'Irony (1332).', 1),
#  (u'calls this chapter "_eines der wichtigsten im ganzen Tractat_", but', 1),
#  (u'which acquires dignity by hearing of the things the eye has seen. If', 1),
#  (u'Objects seen with two eyes will appear rounder than if they are seen', 1),
#  (u'misfortune. This will lead to the commission of endless crimes; this', 1),
#  (u'moon, would be seen in bright light, at which time the moon is in', 1),
#  (u'[Make the vents in the mould while it is on the horse.]', 1),
#  (u'part transparent and light, and will stand out against the dark', 1),
#  (u'presses on its base, and in proportion as it settles and spreads all', 1),
#  (u'OF PERSPECTIVE.', 1),
#  (u"however, as Kleomedes' Cyclia Theorica was not printed till 1535,", 1),
#  (u'Beware of the teaching of these speculators, because their reasoning', 1),
#  (u'[Footnote: This note enables us to fix the date of the Manuscript,', 1),
#  (u'_b_ is badly placed under the pier _d_, because this latter is', 1),
#  (u'[Footnote: This note seems to be a quotation.]', 1),
#  (u'No sooner is Virtue born than Envy comes into the world to attack', 1),
#  (u'having laughed she said: "I know man to be of such ingenuity that', 1),
#  (u'Behold here O reader! a thing concerning which we cannot trust our', 1),
#  (u'III. The letters _a b e d_ and _r_ are not reproduced in facsimile', 1),
#  (u'Gutenberg file.  Please do not remove it.  Do not change or edit the', 1),
#  (u'regarded as an Index, not far short of complete, of all Leonardo s', 1),
#  (u'The darkness of the derived shadow diminishes in proportion as it is', 1),
#  (u'Mamelook supremacy over Syria, which corresponded in date with', 1),
#  (u'Of flower seeds.', 1),
#  (u'even if they are rich, noble and most handsome. Certainly this seems', 1),
#  (u'here alluded to would seem to symbolise their superiority to all', 1),
#  (u'side of the earth continually rises and the antipodes sink closer to', 1),
#  (u'Men will take pleasure in seeing their own work destroyed and', 1),
#  (u'the nut, and this being crushed along with the nuts and being of a', 1),
#  (u'virtue, has no intersection; and this has no sensible dimensions', 1),
#  (u'back he balances the weight in front, in such a way as that the foot', 1),
#  (u'of a capital must measure the fourth part of a square)._', 1),
#  (u'Just as all lines can meet at a point without interfering with each', 1),
#  (u'ones with their shells separated, near to where the rivers fell into', 1),
#  (u'from Valenza, and over that with ashes.', 1),
#  (u'the real tree is close by the side of the tree you have drawn; then', 1),
#  (u'various places.)', 1),
#  (u'that when the moon eclipses the sun, the sun ought not to appear the', 1),
#  (u'Leonardo, and unless we admit personal intercourse--which seems', 1),
#  (u'by the atmosphere [only] and in consequence of this light will tend', 1),
#  (u'A man was desired to rise from bed, because the sun was already', 1),
#  (u'remained unknown, as well as those which treat of the countries', 1),
#  (u'wet clay and the figure consequently increases or grows. _Tu farai', 1),
#  (u'mathematical point is indivisible because it has no size.', 1),
#  (u'only his eye is between the shaded and the illuminated portions of', 1),
#  (u'proceed in this way: When you have drawn the same thing so many', 1),
#  (u'his death, should try to decipher these manuscripts with a view to', 1),
#  (u'OF THE PROOF THAT THE SUN IS HOT BY NATURE AND NOT BY VIRTUE.', 1),
#  (u'it; while, on the other hand, it is almost beyond doubt that in the', 1),
#  (u'fallen the fragments of a mountain forming a shore to the swollen', 1),
#  (u'between one time of writing and the next.', 1),
#  (u'inseparable from all objects. But shadow is a more powerful agent', 1),
#  (u'where it stood in the original document. Thus, too, by following the', 1),
#  (u'the nearer light will be less deep than that which falls towards the', 1),
#  (u'together and the walls will hold the floors. Again I remind you', 1),
#  (u'The mind of the painter must resemble a mirror, which always takes', 1),
#  (u'lack of diligence you were to put your trust in some vaunter, who by', 1),
#  (u'mouth, is the third of the distance from the parting of the lips to', 1),
#  (u'813.', 1),
#  (u'when I put aside some money to pay for these things he stole 4', 1),
#  (u'later by another hand; and Leonardo himself wrote afterwards on the', 1),
#  (u'malignity, would always terrify them.', 1),
#  (u'refers to line 22. The drawing fig. 6 is, in the original, over line', 1),
#  (u'Both the cloud and the tree display no roundness at all on their', 1),
#  (u'Folly is the shield of shame, as unreadiness is that of poverty', 1),
#  (u'_III. Castles and Villas.', 1),
#  (u'erecting a monument to his father Francesco Sforza could be carried', 1),
#  (u'these portions of the illuminated body.', 1),
#  (u'diverted into canals in which the level of the water will not vary', 1),
#  (u']', 1),
#  (u'distant from his fulcrum, and to this is added the force given by', 1),
#  (u'attitude carrying a dimly sketched rider, in the foreground of', 1),
#  (u'1543.', 1),
#  (u'made us with a neck which bends with ease in many directions, the', 1),
# ...
#  (u'generated; and we will say that the voice is, as it were, the', 1),
#  (u'been a favourite with the Diodario. Compare lines 54 and 55.', 1),
#  (u'manuscripts refer to this subject._', 1),
#  (u'This animal, with his thundering roar, rouses his young the third', 1),
#  (u'If you imitate the wings of feathered birds, you will find a much', 1),
#  (u'the price of 8 ducats each ....... duc. 92.', 1),
#  (u'quantity of crystal besides other stones such as are ...', 1),
#  (u'WHETHER THE COLOURS OF THE RAINBOW ARE PRODUCED BY THE SUN.', 1),
#  (u'this group; and, indeed it probably suggested it. The fact that we', 1),
#  (u"d'Angouleme, Louis XII lui avait constitue en dot les comtes de", 1),
#  (u'Here the eye is in the middle, at the point _a_ and near to the', 1),
#  (u'improbable that it should be this princess who is here spoken of as', 1),
#  (u'But if the luminous body is also in movement with a velocity equal', 1),
#  (u'Starting from the shore of Cilicia towards the South you discover', 1),
#  (u'Polemics, have been included in this section as occur as independent', 1),
#  (u'object will never be equal to the extent of surface of the', 1),
#  (u"Again throw vessels of glass full of pitch on to the enemy's ships", 1),
#  (u'seem that it ought to bear 4 times the weight; but by the above rule', 1),
#  (u'nocturnal animals, the horned owl--a bird which is the largest of', 1),
#  (u'On the formation of Gulfs (950. 951).', 1),
#  (u'the back [upper side] of the feet, because nature desired to make', 1),
#  (u'outline of the shadow as it falls on inequalities in the surface', 1),
#  (u'Daldi,--               the Pazzi,', 1),
#  (u'1037.', 1),
#  (u'Answer to Maestro Andrea da Imola, who said that the solar rays', 1),
#  (u'distant mountains appear blue and red glass makes objects seen', 1),
#  (u'723.', 1),
#  (u'794.', 1),
#  (u'al cavallo del Colleoni. E si direbbe che questo fosse figlio del', 1),
#  (u'Pl. XCI, No. 2 above; the exterior of the preceding figure,', 1),
#  (u'Pl. XCI, No. 2 (MS. Ash. 11. 8b) [Footnote 2: The note accompanying', 1),
#  (u'mention a few studies for pictures of the Madonna which probably', 1),
#  (u'the ocean can be lower than that ocean.', 1),
#  (u'at the tops of high mountains; as the lake near Pietra Pana and the', 1),
#  (u'are produced by the light which causes and surrounds the shadows.', 1),
#  (u'Let 4 be the side of an illuminated surface 4 8, surrounding the', 1),
#  (u'of chestnuts of 9 braccia and one out of an average of 100 will be', 1),
#  (u'&c.', 2),
#  (u'1220.', 1),
#  (u'The first year-', 1),
#  (u'The canal had been made in 1460 by Bertonino da Novara. Il Moro', 1),
#  (u'_VII._', 1),
#  (u'channel _f l_, _g h_, _n m_, and reunites with the river from which', 1),
#  (u'la statua_ would then mean, you must work out the figure in marble.', 1),
#  (u'Signoria, perhaps by some historian commissioned by them, to serve', 1),
#  (u'1268.', 1),
#  (u'OF THE SUPPORTS.', 1),
#  (u'as in mist or dense atmosphere, only those portions are seen in', 1),
#  (u'through 3000 miles of Africa; there is also the Bagrada river and', 1),
#  (u'has already been contradicted by Amoretti "Memorie storiche" cap.', 1),
#  (u'which meet at their angles. Hence, if, as [my] opponent says, the', 1),
#  (u'When, Oh draughtsmen, you desire to find relaxation in games you', 1),
#  (u'I say that the deluge could not carry objects, native to the sea, up', 1),
#  (u'1051.', 1),
#  (u'should always practise such things as may be of use in your', 1),
#  (u'strip of iron with a small round hole in the middle about as large', 1),
#  (u'From the chin to the jaw bone _v x_ is half the head and equal to', 1),
#  (u'be behind some tree, with their arms round it that the wind may not', 1),
#  (u'practically and clearly understand how objects transmit their own', 1),
#  (u'rash to assert that Leonardo was the first to introduce the science', 1),
#  (u'solar rays, nor on a dark background; since the roofs of the houses', 1),
#  (u'reproduction these are shown in part. The semi circle above is', 1),
#  (u'Which is the part in man, which, as he grows fatter, never gains', 1),
#  (u'[Footnote: Compare with this the sketches on the other page of the', 1),
#  (u'_Six books on Light and Shade._', 1),
#  (u'1462.', 1),
#  (u'which are most luminous appear the largest. As may be seen by the', 1),
#  (u'with every vice. But of what use is it to fatigue myself with vain', 1),
#  (u'between the mouth and the roots of the hair, that is three quarters', 1),
#  (u'81.', 1),
#  (u'it in the real object _c d_. Hence it is impossible to see it, as', 1),
#  (u'perceive it, to cut it with a long stick while it is still in a', 1),
#  (u'the extended light in half tint, afterwards adding the half lights', 1),
#  (u'part goes 3 times into the length, thus making 3 squares.', 1),
#  (u'_g_, and _b_ which is below will go up to the spot _f_; it will be', 1),
#  (u'to the said treasurers.', 1),
#  (u'886.', 1),
#  (u"(293).--The practice of the Prospettiva de' colori (294).--The rules", 1),
#  (u'must be a great deal of water inside the earth, besides that which', 1),
#  (u'wood cuts. AMORETTI mentions six different ones in the Ambrosian', 1),
#  (u'brows to his companion [6]. Another with his hands spread open shows', 1),
#  (u'your family without payment of any rent." Then the magpie, having', 1),
#  (u'under the porticoes may be lighted; _c d f_ is the place where the', 1),
#  (u'It is indispensable to a Painter who would be thoroughly familiar', 1),
#  (u'the whole of the lost cartoon from the mass of materials we now have', 1),
#  (u'On foolishness and ignorance (1180--1182).', 1),
#  (u'that extend between the object and the eye, when they are directed', 1),
#  (u"chiffre_ 8 _et, a la fin de l'alinea precedent, le chiffre_ 7 _sont,", 1),
#  (u'other, "How do you suppose that a Merchant like me should go about', 1),
#  (u'moon being of varying thinness or density; but if this were so, when', 1),
#  (u'When the eye is placed between the luminous body and the objects', 1),
#  (u'_d_ thrust downwards.', 1),
#  (u'translation by Guarinus Veronensis, which was printed as early as', 1),
#  (u'And for squaring the stones duc. 6.', 1),
#  (u'than from having the man on his back. Hence, here, by 2 methods it', 1),
#  (u'in the State.', 1),
#  (u'On Friday morning,', 1),
#  (u'which will transport a large part of Africa which lies under that', 1),
#  (u'good.', 1),
#  (u'When a man kneels down with his hands folded on his breast the navel', 1),
#  (u'the small body]--always has its shadow cast on the nearest surface', 1),
#  (u'170.', 1),
#  (u"to France, '_come trofeo di vittoria_'!] and which treats of", 1),
#  (u'[Footnote: A straightened leg in profile is sketched by the side of', 1),
#  (u'the sense of the passage, as I understand it, is that by the', 1),
#  (u'Nile again springs from three very high lakes in Ethiopia, and runs', 1),
#  (u'[Footnote: In the original MS. the text of No. 252 precedes the one', 1),
#  (u'&c. Compare also MS. E 15b and F 60b. The principles of astronomical', 1),
#  (u'which sounded like a terrific clap of thunder; and placing his hands', 1),
#  (u'growth of the branches (397--402).--The direction of growth', 1),
#  (u'derived from the original texts, which were supposed to have been', 1),
#  (u'Vinegar ... and a little salt two pieces of canvas for Salai.', 1),
#  (u'In objects of minute size the extent of error is not so perceptible', 1),
#  (u'The beginnings and ends of shadow lie between the light and darkness', 1),
#  (u'Leonardo himself, and on the spot. It is self-evident that the few', 1),
#  (u'rivals and opponents more closely. His protest is directed against', 1),
#  (u'octagonal.', 1),
#  (u'The pen must necessarily have the penknife for a companion, and it', 1),
#  (u'command such violent forces would be lord of the nations, and no', 1),
#  (u'in Naples. His ruined fortunes, it would seem, induced him to join', 1),
#  (u'arms and head before [the mass of] his body, then the outlines of', 1),
#  (u'1558.', 1),
#  (u'reach the point within the eye in straight lines.', 1),
#  (u'plain; hence this plain _d b_ so ends where the sphere of water', 1),
#  (u'LIII, and Pl. LIV--where we also find some studies of foot soldiers', 1),
#  (u'light, because, there, nothing will be visible but the tops of the', 1),
#  (u'two. For, even if his appointment_ (offitio) _as Engineer in Syria', 1),
#  (u'fourth part of the hand and of the face.', 1),
#  (u'is here a slip of the pen since the the words in the MS. are: _"Come', 1),
#  (u'first been called upon to carry out the scheme.]', 1),
#  (u'1121.', 1),
#  (u'other object, which surrounds that original source can be seen by', 1),
#  (u'skins of large beasts.', 1),
#  (u'567.', 1),
#  (u'419.', 1),
#  (u'"Alpine-glow" is certainly not an invented fiction, for in the next', 1),
#  (u'circular plan, in water colour, of Imola--see Pl. CXI No. 1.--In the', 1),
#  (u'folds even and kills them.', 1),
#  (u'OF A MIXTURE OF NATURAL AND ARTIFICIAL PERSPECTIVE.', 1),
#  (u'OF SMALL FOLDS IN DRAPERIES.', 1),
#  (u'ON PAINTING AND PERSPECTIVE.', 1),
#  (u'Light and Shade. Certainly, the Principles of Light and Shade form', 1),
#  (u'so little of the invention attributed to Leonardo of making', 1),
#  (u'[Footnote: See PLINY, Hist. Nat. II, CIII [C]. _Itaque Solis ardore', 1),
#  (u'The notes and dissertations on the texts on Architecture in Vol. II', 1),
#  (u'on opposite objects.', 1),
#  (u'of the extremes on each side of the centre included between them.]', 1),
#  (u'Pl. C, No. 2 (Tr. 21). Plan of the octagon tower, giving the', 1),
#  (u'shadows sharp and too strongly different from the lights.', 1),
#  (u'of urine and also of all the natural excretions of the body.', 1),
#  (u'[Footnote: _"Mundini anatomia. Mundinus, Anothomia (sic). Mundini', 1),
#  (u'side towards the eye a pole were placed, or some other straight', 1),
#  (u'valleys surrounding its base, and on its sides let the surface of', 1),
#  (u'equal to the greatest thickness of the arm in front; but the first', 1),
#  (u'his friends or at the court festivals of princes and patrons._ Era', 1),
#  (u'they are seen from. If you see a figure as large as nature you know', 1),
#  (u'equatorial seas are higher than the waters of the North, and higher', 1),
#  (u'muscles which compose the portion of the tongue which moves in the', 1),
#  (u'and sometimes short. And this is caused by the clouds on the horizon', 1),
#  (u'(Of Friars, who spending nothing but words, receive great gifts and', 1),
#  (u'intermingling of the shaded and illuminated spots comes to the eye', 1),
#  (u'surrounded by deeper shadow. [Footnote: The diagram which, in the', 1),
#  (u'body which casts the cone of shadow.', 1),
#  (u"[Footnote: 669. This passage does not seem to me to be in Leonardo's", 1),
#  (u"Nel 'Catalogo di manoscritti' posseduti da D. Baldassare de'", 1),
#  (u'the altar, or perhaps the central monument on the level of the', 1),
#  (u'channels through which they might come to the sperm.', 1),
#  (u'any commercial products without permission.', 1),
#  (u'In your anatomy you must represent all the stages of the limbs from', 1),
#  (u'[As to how a figure should stand with a weight in its hand [Footnote', 1),
#  (u'That part of the body will be most illuminated which is hit by the', 1),
#  (u'Which are the muscles which subdivide in old age or in youth, when', 1),
#  (u'upwards with bunches of juniper sprigs, the tops downwards, that is', 1),
#  (u'equality of one thing to another.', 1),
#  (u'is almost fluid.', 1),
#  (u'Leonardo was open to it, since we find among his sketches the plan', 1),
#  (u'follows on this subject: "With reference to Rhodes Ross says (_Reise', 1),
#  (u'smaller in size, when the eye sees it through a smaller opening. A', 1),
#  (u'with the dark hue to compose a blue colour; and this light is', 1),
#  (u'that in dimensions and size, as determined by perspective, nothing', 1),
#  (u'paid for his painting of the "_proditores_". We can however hardly', 1),
#  (u'destroy cities and castles.', 1),
#  (u'temple and adored by men in the place of Jove, while you are bound', 1),
#  (u'works of fame by which I could show to', 1),
#  (u'[Footnote 24: _la prima di sopra_ i. e. the first of the three', 1),
#  (u"Leonardo's design.", 1),
#  (u'Amboise.]', 1),
#  (u'the waves of the sea at one end and in each complete revolution', 1),
#  (u'their diminution makes the whole mass of the object look smaller.', 1),
#  (u'sketch on the page W. L. 145 b corresponds to the middle sketch of', 1),
#  (u'A pall over the bier 12 S', 1),
#  (u'beneath the body of the sun than in any part of the equatorial', 1),
#  (u'994.', 1),
#  (u'painting as the principles of the Proportions and Movements of the', 1),
#  (u'675.', 1),
#  (u'same type.', 1),
#  (u'understand that old age has wisdom for its food, you will so conduct', 1),
#  (u'an arrow. [Footnote: This note must have been made in Milan; as we', 1),
#  (u'the wall settles more than the stone facing, the projections left on', 1),
#  (u'solid since they are seen from two distinct points of sight', 1),
#  (u'be less distinct in proportion as they are closer to the eye. This', 1),
#  (u'23.', 1),
#  (u'men.', 1),
#  (u'On the treatment of light for landscapes (458-464).', 1),
#  (u'we can see. And from the base line of the first pyramid as far as', 1),
#  (u'lighted by the sun within the half of the horizon that is the', 1),
#  (u'THE MACLI.--CAUGHT WHEN ASLEEP.', 1),
#  (u'portions--such as the very important rules for the proportions of', 1),
#  (u'various positions of those objects. Let _o_ be a blue object in full', 1),
#  (u'We are constantly working on finishing the paperwork to legally', 1),
#  (u'the Nile a fall of 1 braccia in every mile.', 1),
#  (u'appear as a blue shadow on a red background tinted with blue,', 1),
#  (u'[Footnote: Lines 1--5l are in the original written in one column,', 1),
#  (u'Manuscripts at the beginning of Volume I, and to the Bibliography at', 1),
#  (u'(Of the Mouth of Man, which is a Sepulchre.)', 1),
#  (u'innumerable rivers which join them, and which always run turbid with', 1),
#  (u"Leonardo's views as to Alchemy, Ghosts, Magicians, and the like", 1),
#  (u'Then describe the fully grown man and woman, with their proportions,', 1),
#  (u"as they occur in the original, we may follow the author's mind; and", 1),
#  (u'Blackbird, I am here, and not yet burnt by fire as you said. I shall', 1),
#  (u'May than in September.', 1),
#  (u'1396.', 1),
#  (u'give me possession of this water, because on my return I hope to', 1),
#  (u'(465-469). _To the theory of Landscape Painting belong also the', 1),
#  (u'http://gutenberg.net or', 1),
#  (u'downwards; with white stems; this transparent in the air, that not;', 1),
#  (u'_r t_; it sees the surface of the image at _r t_, and does not see', 1),
#  (u'garden which is outside the walls of Milan, and the other half of', 1),
#  (u'mirror.', 1),
#  (u'the rays thrown off by a shaded or illuminated body passing through', 1),
#  (u'This victory and triumph, historians tell us, were signalised by', 1),
#  (u'253.', 1),
#  (u'with you this Easter and carry with me two pictures on which are two', 1),
#  (u'Inventories and accounts (1509--1545).', 1),
#  (u'wrist joint of the hand to the point of the elbow. [14] The foot is', 1),
#  (u'An eagle wanting to mock at the owl was caught by the wings in', 1),
#  (u'There are three branches of perspective; the first deals with the', 1),
#  (u'and "latastro" seems to have been little in use. It is to be found', 1),
#  (u'sinuous stream from the corpse. Others must be represented in the', 1),
#  (u'devours it.', 1),
#  (u'which the columns are placed. This method is not satisfactory unless', 1),
#  (u'Gibraltar; and again it is caused by whirlpools.', 1),
#  (u'maps; and all the less since the foregoing chapters clearly prove', 1),
#  (u'That the blood which returns when the heart opens again is not the', 1),
#  (u'not been altered since Leonardo used them. The assistance these', 1),
#  (u'CHRIST.', 1),
#  (u'1442.', 1),
#  (u'507.', 1),
#  (u'to melt the copper.', 1),
#  (u'Histoire des sciences mathematiques en Italie (II, 216, 217): "On a', 1),
#  (u'him, are not to be found in the manuscripts, and Prof. Uzielli has', 1),
#  (u'in dinari of 5 1/2 soldi 1.  29 S 13', 1),
#  ...]
