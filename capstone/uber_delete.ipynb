# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import time
from datetime import datetime

sns.set_style('whitegrid')

import multiprocessing
cpu_cores = multiprocessing.cpu_count()

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
### TL;DR -> TRAFFIC DATA NOT AVAILABLE
### COUNTINOUS COUNT (CC) NYDOT DATA DOES NOT HAVE REGION 04 (NEW YORK) DATA
### SHORT COUNT (SC) NYDOT DATA DOES HAVE ALL REGIONS BUT ONLY MONTHS 8 - 12

# %%
###

# %%
link = "https://app.ticketmaster.com/discovery/v2/events.json?dmaId=345&startDateTime=2015-02-01T00:00:00Z&apikey=fVbazqJFcZngO05vCs8bJEW1DCLFL41j"

# %%
import urllib

link = "https://app.ticketmaster.com/discovery/v2/events.json?dmaId=345&startDateTime=2015-02-01T00:00:00Z&apikey=fVbazqJFcZngO05vCs8bJEW1DCLFL41j"
f = urllib.urlopen(link)
myfile = f.read()
print myfile
# Out:
# {"_embedded":{"events":[{"name":"Billy Joel - In Concert","type":"event","id":"G5diZf92c2-HI","test":false,"url":"http://ticketmaster.com/event/3B005173ED3E1F28","locale":"en-us","images":[{"ratio":"16_9","url":"https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RECOMENDATION_16_9.jpg","width":100,"height":56,"fallback":true},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_PORTRAIT_16_9.jpg","width":640,"height":360,"fallback":true},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_LARGE_16_9.jpg","width":2048,"height":1152,"fallback":true},{"ratio":"3_2","url":"https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_PORTRAIT_3_2.jpg","width":640,"height":427,"fallback":true},{"ratio":"16_9","url":"https://s1.ticketm.net/dbimages/160694a.jpg","width":205,"height":115,"fallback":false},{"ratio":"16_9","url":
# ...

# %%
import json
parsed_json = json.loads(myfile)

# %%
n = 19
print 'name =\t\t', parsed_json['_embedded']['events'][n]['_embedded']['venues'][0]['name']
print 'Line 1 =\t', parsed_json['_embedded']['events'][n]['_embedded']['venues'][0]['address']['line1']
print 'ZIP =\t\t',parsed_json['_embedded']['events'][n]['_embedded']['venues'][0]['postalCode']
print 'localDate =\t',parsed_json['_embedded']['events'][n]['dates']['start']['localDate']
print 'localTime =\t', parsed_json['_embedded']['events'][n]['dates']['start']['localTime']
print 'latitude =\t', parsed_json['_embedded']['events'][n]['_embedded']['venues'][0]['location']['latitude']
print 'longitude =\t',parsed_json['_embedded']['events'][n]['_embedded']['venues'][0]['location']['longitude']
# Out:
# name =		The Theater at Madison Square Garden
# Line 1 =	7th Ave & 32nd Street
# ZIP =		10001
# localDate =	2017-04-01
# localTime =	20:00:00
# latitude =	40.7497062
# longitude =	-73.9916006

# %%
# print parsed_json.keys(), '\n'
# print parsed_json['_embedded'].keys(), '\n'
# print parsed_json['_embedded']['events'][0].keys(), '\n'
# print parsed_json['_embedded']['events'][0]['_embedded'].keys(), '\n'
# print parsed_json['_embedded']['events'][0]['_embedded']['venues'][0].keys(), '\n'
# print parsed_json['_embedded']['events'][0]['_embedded']['venues'][0]['id'], '\n'

# %%
### INSERT SHORT COUNT (SC) DATA

sc_data = pd.read_csv('/Users/austinwhaley/Downloads/SC_Volume_Data_R11_2015.csv')
columns = []
for i in sc_data.columns:
    columns.append(i.strip())
sc_data.columns = columns

def county_name_insert(x):
    if x == 1:
        return 'BRONX'
    if x == 2:
        return 'KINGS'
    if x == 4:
        return 'NEW YORK'
    if x == 5:
        return 'QUEENS'
    if x == 6:
        return 'RICHMOND'
    else:
        return 'ERROR'


COUNTY_NAME = sc_data['COUNTY_CODE'].map(county_name_insert)
sc_data.insert(5, 'COUNTY_NAME', COUNTY_NAME)
drop_columns = ['RC_STATION', 'COUNT_ID', 'RG', 'REGION_CODE', 'STAT', 'RCSTA', 'FUNCTIONAL_CLASS', 'FACTOR_GROUP',
               'LATITUDE', 'LONGITUDE', 'SPECIFIC_RECORDER_PLACEMENT', 'CHANNEL_NOTES', 'DATA_TYPE',
               'VEHICLE_AXLE_CODE', 'FEDERAL_DIRECTION', 'LANE_CODE', 'LANES_IN_DIRECTION', 'COLLECTION_INTERVAL',
               'TOTAL', 'FLAG_FIELD', 'BATCH_ID']
sc_data = sc_data.drop(drop_columns, 1)
print 'IMPORTED ||', str(datetime.now())
# Out:
# IMPORTED || 2017-01-22 13:22:04.553819

# %%
for i in sc_data.columns:
    print i
# Out:
# COUNTY_CODE
# COUNTY_NAME
# YEAR
# MONTH
# DAY
# DAY_OF_WEEK
# INTERVAL_1_1
# INTERVAL_1_2
# INTERVAL_1_3
# INTERVAL_1_4
# INTERVAL_2_1
# INTERVAL_2_2
# INTERVAL_2_3
# INTERVAL_2_4
# INTERVAL_3_1
# INTERVAL_3_2
# INTERVAL_3_3
# INTERVAL_3_4
# INTERVAL_4_1
# INTERVAL_4_2
# INTERVAL_4_3
# INTERVAL_4_4
# INTERVAL_5_1
# INTERVAL_5_2
# INTERVAL_5_3
# INTERVAL_5_4
# INTERVAL_6_1
# INTERVAL_6_2
# INTERVAL_6_3
# INTERVAL_6_4
# INTERVAL_7_1
# INTERVAL_7_2
# INTERVAL_7_3
# INTERVAL_7_4
# INTERVAL_8_1
# INTERVAL_8_2
# INTERVAL_8_3
# INTERVAL_8_4
# INTERVAL_9_1
# INTERVAL_9_2
# INTERVAL_9_3
# INTERVAL_9_4
# INTERVAL_10_1
# INTERVAL_10_2
# INTERVAL_10_3
# INTERVAL_10_4
# INTERVAL_11_1
# INTERVAL_11_2
# INTERVAL_11_3
# INTERVAL_11_4
# INTERVAL_12_1
# INTERVAL_12_2
# INTERVAL_12_3
# INTERVAL_12_4
# INTERVAL_13_1
# INTERVAL_13_2
# INTERVAL_13_3
# INTERVAL_13_4
# INTERVAL_14_1
# INTERVAL_14_2
# INTERVAL_14_3
# INTERVAL_14_4
# INTERVAL_15_1
# INTERVAL_15_2
# INTERVAL_15_3
# INTERVAL_15_4
# ...

# %%
sc_data.groupby(['YEAR', 'MONTH']).count()
# Out:
#             COUNTY_CODE  COUNTY_NAME   DAY  DAY_OF_WEEK  INTERVAL_1_1  \
# YEAR MONTH
# 2015 8             1376         1376  1376         1376          1376
#      9             3548         3548  3548         3548          3548
#      10            3692         3692  3692         3692          3692
#      11            2737         2737  2737         2737          2737
#      12            1828         1828  1828         1828          1828
#
#             INTERVAL_1_2  INTERVAL_1_3  INTERVAL_1_4  INTERVAL_2_1  \
# YEAR MONTH
# 2015 8              1376          1376          1376          1376
#      9              3548          3548          3548          3548
#      10             3692          3692          3692          3692
#      11             2737          2737          2737          2737
#      12             1828          1828          1828          1828
#
#             INTERVAL_2_2      ...        INTERVAL_22_3  INTERVAL_22_4  \
# YEAR MONTH                    ...
# ...

# %%
sc_data['MONTH'].count()
# Out:
# 13181

# %%
sc_data.shape
# Out:
# (13181, 102)

# %%
airlines = [paste data]
for airline in airlines:
    while len(static_df) <= 5000:
        dynamic_df = mine_user_tweets(airline)
        static_df.concat(dynamic_df)

# %%
zone = pd.read_csv('/Users/austinwhaley/Downloads/nyczoningtaxlotdb201612/NYC_ZoningTaxLotDB_201612.csv')
# Out:
# /Users/austinwhaley/anaconda/envs/dsi/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (6,8,9,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
zone = zone[['Borough Code', 'Tax Block', 'Tax Lot', 'Zoning District 1']]
zone.head()
# Out:
#    Borough Code  Tax Block  Tax Lot Zoning District 1
# 0             1          1       10              R3-2
# 1             1          1      101              R3-2
# 2             1          1      201              R3-2
# 3             1          1      301               ZNA
# 4             1          1      401               ZNA

# %%
zone['Tax Block'].value_counts()
# Out:
# 2925     578
# 7405     539
# 7422     485
# 4452     465
# 869      410
# 4478     389
# 7441     371
# 6022     370
# 1670     366
# 5408     339
# 5626     329
# 5409     326
# 5741     316
# 4500     315
# 6018     310
# 4645     309
# 6023     306
# 377      305
# 2879     298
# 5743     292
# 7356     291
# 5442     291
# 837      290
# 2015     290
# 5518     289
# 7267     289
# 5740     289
# 5489     286
# 391      285
# 2877     285
#         ...
# 15531      1
# 9691       1
# 10723      1
# 15906      1
# 7282       1
# 15885      1
# 11296      1
# 10926      1
# 13943      1
# 8087       1
# 15919      1
# 10626      1
# 15745      1
# 11445      1
# 11640      1
# 15736      1
# 8060       1
# 7721       1
# 15843      1
# 14214      1
# 15976      1
# 7553       1
# 13929      1
# 10118      1
# 10119      1
# 15886      1
# 11882      1
# 13947      1
# 15747      1
# 9067       1
# Name: Tax Block, dtype: int64

# %%
### GOOGLE MAPS DISTANCE MATRIX API KEY
# AIzaSyA0rogrrmQjWyrAIcel2ascIeyMO_xHsAU

# %%
json = pd.read_json(url)
